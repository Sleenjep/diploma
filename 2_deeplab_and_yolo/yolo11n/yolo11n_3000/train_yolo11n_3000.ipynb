# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"

from pathlib import Path
import random
import shutil
import yaml

ROOT = Path.cwd()
LABELS_DIR = ROOT / "labels"
CLASSES_FILE = ROOT / "classes.txt"
ORIG_IMAGES_DIR = Path(r"E:\\SosedTemporary\\WorkingSpace\\Narabotki\\ORIG_valid_images")
WORK_DIR = ROOT / "yolo_dataset_1_0_3"
DATASET_DIR = WORK_DIR / "dataset"
RUNS_DIR = WORK_DIR / "runs"
RUN_NAME = "train"
METRICS_TXT_PATH = WORK_DIR / "metrics_log.txt"
SELECTED_SOURCE_CLASS_IDS = [1, 0, 3]
SEED = 42
EPOCHS = 50
IMGSZ = 640
BATCH = 16
WORKERS = 0
MODEL_WEIGHTS = "yolo11n.pt"
DEVICE = "cuda"
OVERWRITE_WORK_DIR = True

# %%
all_class_names = [line.strip() for line in CLASSES_FILE.read_text(encoding="utf-8").splitlines() if line.strip()]
selected_names = [all_class_names[i] for i in SELECTED_SOURCE_CLASS_IDS]
id_map = {src_id: dst_id for dst_id, src_id in enumerate(SELECTED_SOURCE_CLASS_IDS)}

if WORK_DIR.exists() and OVERWRITE_WORK_DIR:
    shutil.rmtree(WORK_DIR)

(DATASET_DIR / "images" / "train").mkdir(parents=True, exist_ok=True)
(DATASET_DIR / "images" / "val").mkdir(parents=True, exist_ok=True)
(DATASET_DIR / "labels" / "train").mkdir(parents=True, exist_ok=True)
(DATASET_DIR / "labels" / "val").mkdir(parents=True, exist_ok=True)

prepared_items = []
for label_path in sorted(LABELS_DIR.glob("*.txt")):
    stem_parts = label_path.stem.split("-")
    if len(stem_parts) != 2:
        continue
    image_id = stem_parts[1]
    image_path = ORIG_IMAGES_DIR / f"{image_id}.png"
    if not image_path.exists():
        continue

    kept = []
    for raw_line in label_path.read_text(encoding="utf-8").splitlines():
        line = raw_line.strip()
        if not line:
            continue
        parts = line.split()
        cls = int(parts[0])
        if cls in id_map:
            parts[0] = str(id_map[cls])
            kept.append(" ".join(parts))

    if kept:
        prepared_items.append((image_id, image_path, kept))

random.seed(SEED)
random.shuffle(prepared_items)
train_items = prepared_items
val_items = []

for image_id, src_image, lines in train_items:
    dst_image = DATASET_DIR / "images" / "train" / f"{image_id}.png"
    dst_label = DATASET_DIR / "labels" / "train" / f"{image_id}.txt"
    shutil.copy2(src_image, dst_image)
    dst_label.write_text("\n".join(lines) + "\n", encoding="utf-8")

data_yaml = {
    "path": str(DATASET_DIR.resolve()),
    "train": "images/train",
    "val": "images/train",
    "nc": len(selected_names),
    "names": selected_names,
}
(WORK_DIR / "data.yaml").write_text(yaml.safe_dump(data_yaml, allow_unicode=True, sort_keys=False), encoding="utf-8")

{
    "total_labeled_images": len(prepared_items),
    "train_images": len(train_items),
    "val_images": len(val_items),
    "selected_source_class_ids": SELECTED_SOURCE_CLASS_IDS,
    "selected_class_names": selected_names,
    "data_yaml": str((WORK_DIR / "data.yaml").resolve()),
}
# Out:
# {'total_labeled_images': 3000,
#  'train_images': 3000,
#  'val_images': 0,
#  'selected_source_class_ids': [1, 0, 3],
#  'selected_class_names': ['лицо', 'голова', 'персонаж'],
#  'data_yaml': 'E:\\SosedTemporary\\WorkingSpace\\Narabotki\\26-05-14_1\\yolo11n_3000_full_train\\yolo_dataset_1_0_3\\data.yaml'}

# %%
import os
import csv
import json
from pathlib import Path

from ultralytics import YOLO
from ultralytics.utils import LOGGER


def _to_float(value):
    try:
        return float(value)
    except Exception:
        return None


def _fmt(value):
    if value is None:
        return "nan"
    return f"{value:.6f}"


def _read_last_row(csv_path: Path):
    if not csv_path.exists():
        return {}
    with csv_path.open("r", encoding="utf-8", newline="") as f:
        rows = list(csv.DictReader(f))
    if not rows:
        return {}
    return rows[-1]


def _get_row_value(row, candidates):
    for key in candidates:
        if key in row and row[key] not in ("", None):
            return _to_float(row[key])
    return None


def _extract_overall(row):
    return {
        "train_box_loss": _get_row_value(row, ["train/box_loss"]),
        "train_cls_loss": _get_row_value(row, ["train/cls_loss"]),
        "train_dfl_loss": _get_row_value(row, ["train/dfl_loss"]),
        "val_box_loss": _get_row_value(row, ["val/box_loss"]),
        "val_cls_loss": _get_row_value(row, ["val/cls_loss"]),
        "val_dfl_loss": _get_row_value(row, ["val/dfl_loss"]),
        "precision": _get_row_value(row, ["metrics/precision(B)", "metrics/precision"]),
        "recall": _get_row_value(row, ["metrics/recall(B)", "metrics/recall"]),
        "map50": _get_row_value(row, ["metrics/mAP50(B)", "metrics/mAP50"]),
        "map50_95": _get_row_value(row, ["metrics/mAP50-95(B)", "metrics/mAP50-95"]),
    }


def _extract_box_metrics(trainer):
    validator = getattr(trainer, "validator", None)
    if validator is None:
        return None
    metrics = getattr(validator, "metrics", None)
    if metrics is None:
        return None
    return getattr(metrics, "box", None)


def _emit(text):
    print(text, flush=True)
    LOGGER.info(text)


def _on_train_epoch_end(trainer):
    epoch = int(getattr(trainer, "epoch", -1)) + 1
    _emit(f"train_epoch_end={epoch}/{EPOCHS}")


def _on_fit_epoch_end(trainer):
    epoch = int(getattr(trainer, "epoch", -1)) + 1
    csv_path = Path(trainer.save_dir) / "results.csv"
    row = _read_last_row(csv_path)
    overall = _extract_overall(row)

    box = _extract_box_metrics(trainer)
    if box is not None and hasattr(box, "mean_results"):
        try:
            mean_p, mean_r, mean_map50, mean_map50_95 = box.mean_results()
            if overall["precision"] is None:
                overall["precision"] = _to_float(mean_p)
            if overall["recall"] is None:
                overall["recall"] = _to_float(mean_r)
            if overall["map50"] is None:
                overall["map50"] = _to_float(mean_map50)
            if overall["map50_95"] is None:
                overall["map50_95"] = _to_float(mean_map50_95)
        except Exception:
            pass

    per_class = []
    if box is not None and hasattr(box, "class_result"):
        for class_id, class_name in enumerate(selected_names):
            try:
                class_p, class_r, class_map50, class_map50_95 = box.class_result(class_id)
            except Exception:
                class_p, class_r, class_map50, class_map50_95 = None, None, None, None
            per_class.append(
                {
                    "class_id": class_id,
                    "class_name": class_name,
                    "precision": _to_float(class_p),
                    "recall": _to_float(class_r),
                    "map50": _to_float(class_map50),
                    "map50_95": _to_float(class_map50_95),
                }
            )

    record = {
        "epoch": epoch,
        **overall,
        "per_class": per_class,
    }

    with METRICS_TXT_PATH.open("a", encoding="utf-8") as f:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

    _emit(
        f"epoch={epoch}/{EPOCHS} "
        f"P={_fmt(overall['precision'])} "
        f"R={_fmt(overall['recall'])} "
        f"mAP50={_fmt(overall['map50'])} "
        f"mAP50-95={_fmt(overall['map50_95'])} "
        f"train_box={_fmt(overall['train_box_loss'])} "
        f"train_cls={_fmt(overall['train_cls_loss'])} "
        f"train_dfl={_fmt(overall['train_dfl_loss'])} "
        f"val_box={_fmt(overall['val_box_loss'])} "
        f"val_cls={_fmt(overall['val_cls_loss'])} "
        f"val_dfl={_fmt(overall['val_dfl_loss'])}"
    )

    for cls in per_class:
        _emit(
            f"  class_id={cls['class_id']} "
            f"class_name={cls['class_name']} "
            f"P={_fmt(cls['precision'])} "
            f"R={_fmt(cls['recall'])} "
            f"mAP50={_fmt(cls['map50'])} "
            f"mAP50-95={_fmt(cls['map50_95'])}"
        )


METRICS_TXT_PATH.parent.mkdir(parents=True, exist_ok=True)
METRICS_TXT_PATH.write_text("", encoding="utf-8")

model = YOLO(MODEL_WEIGHTS)
model.add_callback("on_train_epoch_end", _on_train_epoch_end)
model.add_callback("on_fit_epoch_end", _on_fit_epoch_end)
_emit("custom_progress_logging_enabled")

result = model.train(
    data=str((WORK_DIR / "data.yaml").resolve()),
    epochs=EPOCHS,
    imgsz=IMGSZ,
    batch=BATCH,
    workers=WORKERS,
    project=str(RUNS_DIR.resolve()),
    name=RUN_NAME,
    device=DEVICE,
    verbose=True,
)

save_dir = Path(result.save_dir)
artifacts = {
    "save_dir": str(save_dir.resolve()),
    "best_weights": str((save_dir / "weights" / "best.pt").resolve()),
    "last_weights": str((save_dir / "weights" / "last.pt").resolve()),
    "results_csv": str((save_dir / "results.csv").resolve()),
    "metrics_txt": str(METRICS_TXT_PATH.resolve()),
}
artifacts
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 980.9KB/s 5.6ss<0.0s9sss
# custom_progress_logging_enabled
# custom_progress_logging_enabled
# New https://pypi.org/project/ultralytics/8.4.51 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.245  Python-3.10.19 torch-2.11.0.dev20251231+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Ti, 16311MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\runs\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431257  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,425 parameters, 2,590,409 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 747.3358.9 MB/s, size: 5116.0 KB)
# train: Scanning E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\dataset\labels\train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 496.9it/s 6.0s<0.0s
# train: New cache created: E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\dataset\labels\train.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 2939.4389.3 MB/s, size: 4474.9 KB)
# val: Scanning E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\dataset\labels\train.cache... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 3.0Mit/s 0.0s
# Plotting labels to E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\runs\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\runs\train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.37G      1.081      1.722      1.234         38        640: 100% ━━━━━━━━━━━━ 188/188 3.0s/it 9:293.5ss
# train_epoch_end=1/50
# train_epoch_end=1/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.8s/it 9:035.5ss
#                    all       3000       8854      0.853      0.855      0.919      0.693
# epoch=1/50 P=0.853500 R=0.854750 mAP50=0.918820 mAP50-95=0.692970 train_box=1.081430 train_cls=1.722420 train_dfl=1.234280 val_box=0.793130 val_cls=0.855520 val_dfl=1.027710
# epoch=1/50 P=0.853500 R=0.854750 mAP50=0.918820 mAP50-95=0.692970 train_box=1.081430 train_cls=1.722420 train_dfl=1.234280 val_box=0.793130 val_cls=0.855520 val_dfl=1.027710
#   class_id=0 class_name=лицо P=0.854206 R=0.626575 mAP50=0.802091 mAP50-95=0.470924
#   class_id=0 class_name= P=0.854206 R=0.626575 mAP50=0.802091 mAP50-95=0.470924
#   class_id=1 class_name=голова P=0.876413 R=0.957014 mAP50=0.975583 mAP50-95=0.788517
#   class_id=1 class_name= P=0.876413 R=0.957014 mAP50=0.975583 mAP50-95=0.788517
#   class_id=2 class_name=персонаж P=0.829867 R=0.980673 mAP50=0.978793 mAP50-95=0.819468
#   class_id=2 class_name= P=0.829867 R=0.980673 mAP50=0.978793 mAP50-95=0.819468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.37G     0.9839       1.02      1.155         25        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:112.2ss
# train_epoch_end=2/50
# train_epoch_end=2/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:545.5ss
#                    all       3000       8854      0.909      0.895      0.941      0.698
# epoch=2/50 P=0.908790 R=0.895090 mAP50=0.941480 mAP50-95=0.698140 train_box=0.983920 train_cls=1.019580 train_dfl=1.154560 val_box=0.848800 val_cls=0.732760 val_dfl=1.061890
# epoch=2/50 P=0.908790 R=0.895090 mAP50=0.941480 mAP50-95=0.698140 train_box=0.983920 train_cls=1.019580 train_dfl=1.154560 val_box=0.848800 val_cls=0.732760 val_dfl=1.061890
#   class_id=0 class_name=лицо P=0.875775 R=0.800898 mAP50=0.877706 mAP50-95=0.542813
#   class_id=0 class_name= P=0.875775 R=0.800898 mAP50=0.877706 mAP50-95=0.542813
#   class_id=1 class_name=голова P=0.947311 R=0.930357 mAP50=0.975404 mAP50-95=0.773875
#   class_id=1 class_name= P=0.947311 R=0.930357 mAP50=0.975404 mAP50-95=0.773875
#   class_id=2 class_name=персонаж P=0.903274 R=0.954015 mAP50=0.971329 mAP50-95=0.777718
#   class_id=2 class_name= P=0.903274 R=0.954015 mAP50=0.971329 mAP50-95=0.777718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.37G     0.9797     0.9104      1.162         44        640: 100% ━━━━━━━━━━━━ 188/188 3.0s/it 9:152.3ss
# train_epoch_end=3/50
# train_epoch_end=3/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:545.5ss
#                    all       3000       8854      0.899      0.901      0.942       0.71
# epoch=3/50 P=0.899260 R=0.901110 mAP50=0.941830 mAP50-95=0.709500 train_box=0.979710 train_cls=0.910440 train_dfl=1.162290 val_box=0.790810 val_cls=0.666270 val_dfl=1.044510
# epoch=3/50 P=0.899260 R=0.901110 mAP50=0.941830 mAP50-95=0.709500 train_box=0.979710 train_cls=0.910440 train_dfl=1.162290 val_box=0.790810 val_cls=0.666270 val_dfl=1.044510
#   class_id=0 class_name=лицо P=0.901845 R=0.782848 mAP50=0.882899 mAP50-95=0.538314
#   class_id=0 class_name= P=0.901845 R=0.782848 mAP50=0.882899 mAP50-95=0.538314
#   class_id=1 class_name=голова P=0.945116 R=0.946806 mAP50=0.981466 mAP50-95=0.805938
#   class_id=1 class_name= P=0.945116 R=0.946806 mAP50=0.981466 mAP50-95=0.805938
#   class_id=2 class_name=персонаж P=0.850813 R=0.973675 mAP50=0.961133 mAP50-95=0.784250
#   class_id=2 class_name= P=0.850813 R=0.973675 mAP50=0.961133 mAP50-95=0.784250
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.37G     0.9545     0.8179      1.146         42        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:102.3ss
# train_epoch_end=4/50
# train_epoch_end=4/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.6s/it 8:515.5ss
#                    all       3000       8854      0.815      0.809      0.879      0.616
# epoch=4/50 P=0.814560 R=0.808640 mAP50=0.879230 mAP50-95=0.616380 train_box=0.954460 train_cls=0.817940 train_dfl=1.145750 val_box=0.934300 val_cls=0.838260 val_dfl=1.123950
# epoch=4/50 P=0.814560 R=0.808640 mAP50=0.879230 mAP50-95=0.616380 train_box=0.954460 train_cls=0.817940 train_dfl=1.145750 val_box=0.934300 val_cls=0.838260 val_dfl=1.123950
#   class_id=0 class_name=лицо P=0.906504 R=0.775103 mAP50=0.888569 mAP50-95=0.522599
#   class_id=0 class_name= P=0.906504 R=0.775103 mAP50=0.888569 mAP50-95=0.522599
#   class_id=1 class_name=голова P=0.827942 R=0.894733 mAP50=0.913005 mAP50-95=0.717352
#   class_id=1 class_name= P=0.827942 R=0.894733 mAP50=0.913005 mAP50-95=0.717352
#   class_id=2 class_name=персонаж P=0.709242 R=0.756081 mAP50=0.836111 mAP50-95=0.609175
#   class_id=2 class_name= P=0.709242 R=0.756081 mAP50=0.836111 mAP50-95=0.609175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.37G      0.923     0.7507      1.127         65        640: 100% ━━━━━━━━━━━━ 188/188 3.0s/it 9:152.3ss
# train_epoch_end=5/50
# train_epoch_end=5/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:605.5ss
#                    all       3000       8854      0.933      0.934      0.967      0.777
# epoch=5/50 P=0.932880 R=0.934370 mAP50=0.967240 mAP50-95=0.777190 train_box=0.922970 train_cls=0.750720 train_dfl=1.126790 val_box=0.705620 val_cls=0.517500 val_dfl=0.989350
# epoch=5/50 P=0.932880 R=0.934370 mAP50=0.967240 mAP50-95=0.777190 train_box=0.922970 train_cls=0.750720 train_dfl=1.126790 val_box=0.705620 val_cls=0.517500 val_dfl=0.989350

#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.37G       0.85     0.6487      1.088         60        640: 100% ━━━━━━━━━━━━ 188/188 3.0s/it 9:152.3ss
# train_epoch_end=8/50
# train_epoch_end=8/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:575.6ss
#                    all       3000       8854      0.932      0.919      0.961      0.764
# epoch=8/50 P=0.931770 R=0.919060 mAP50=0.960600 mAP50-95=0.763890 train_box=0.849960 train_cls=0.648700 train_dfl=1.088240 val_box=0.726040 val_cls=0.509490 val_dfl=1.014630
# epoch=8/50 P=0.931770 R=0.919060 mAP50=0.960600 mAP50-95=0.763890 train_box=0.849960 train_cls=0.648700 train_dfl=1.088240 val_box=0.726040 val_cls=0.509490 val_dfl=1.014630
#   class_id=0 class_name=лицо P=0.906448 R=0.862925 mAP50=0.922676 mAP50-95=0.621496
#   class_id=0 class_name= P=0.906448 R=0.862925 mAP50=0.922676 mAP50-95=0.621496
#   class_id=1 class_name=голова P=0.966525 R=0.972343 mAP50=0.990751 mAP50-95=0.848868
#   class_id=1 class_name= P=0.966525 R=0.972343 mAP50=0.990751 mAP50-95=0.848868
#   class_id=2 class_name=персонаж P=0.922325 R=0.921922 mAP50=0.968363 mAP50-95=0.821297
#   class_id=2 class_name= P=0.922325 R=0.921922 mAP50=0.968363 mAP50-95=0.821297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.37G     0.8326     0.6376      1.082         34        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:132.3ss
# train_epoch_end=9/50
# train_epoch_end=9/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:565.5ss
#                    all       3000       8854      0.951      0.945      0.974       0.82
# epoch=9/50 P=0.951250 R=0.944630 mAP50=0.973980 mAP50-95=0.819950 train_box=0.832560 train_cls=0.637620 train_dfl=1.081960 val_box=0.590120 val_cls=0.438760 val_dfl=0.939940
# epoch=9/50 P=0.951250 R=0.944630 mAP50=0.973980 mAP50-95=0.819950 train_box=0.832560 train_cls=0.637620 train_dfl=1.081960 val_box=0.590120 val_cls=0.438760 val_dfl=0.939940
#   class_id=0 class_name=лицо P=0.939571 R=0.877733 mAP50=0.941200 mAP50-95=0.683282
#   class_id=0 class_name= P=0.939571 R=0.877733 mAP50=0.941200 mAP50-95=0.683282
#   class_id=1 class_name=голова P=0.952248 R=0.976818 mAP50=0.988916 mAP50-95=0.875385
#   class_id=1 class_name= P=0.952248 R=0.976818 mAP50=0.988916 mAP50-95=0.875385
#   class_id=2 class_name=персонаж P=0.961937 R=0.979340 mAP50=0.991817 mAP50-95=0.901197
#   class_id=2 class_name= P=0.961937 R=0.979340 mAP50=0.991817 mAP50-95=0.901197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.37G     0.8143      0.615      1.074         27        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:112.3ss
# train_epoch_end=10/50
# train_epoch_end=10/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94

#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.37G     0.7923      0.586      1.056         46        640: 100% ━━━━━━━━━━━━ 188/188 3.0s/it 9:152.3ss
# train_epoch_end=13/50
# train_epoch_end=13/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:575.5ss
#                    all       3000       8854      0.964      0.963      0.983      0.846
# epoch=13/50 P=0.963850 R=0.963000 mAP50=0.982610 mAP50-95=0.845660 train_box=0.792320 train_cls=0.585970 train_dfl=1.056450 val_box=0.542770 val_cls=0.375330 val_dfl=0.906050
# epoch=13/50 P=0.963850 R=0.963000 mAP50=0.982610 mAP50-95=0.845660 train_box=0.792320 train_cls=0.585970 train_dfl=1.056450 val_box=0.542770 val_cls=0.375330 val_dfl=0.906050
#   class_id=0 class_name=лицо P=0.943512 R=0.913624 mAP50=0.961561 mAP50-95=0.721367
#   class_id=0 class_name= P=0.943512 R=0.913624 mAP50=0.961561 mAP50-95=0.721367
#   class_id=1 class_name=голова P=0.972323 R=0.983360 mAP50=0.991916 mAP50-95=0.888588
#   class_id=1 class_name= P=0.972323 R=0.983360 mAP50=0.991916 mAP50-95=0.888588
#   class_id=2 class_name=персонаж P=0.975721 R=0.992003 mAP50=0.994359 mAP50-95=0.927030
#   class_id=2 class_name= P=0.975721 R=0.992003 mAP50=0.994359 mAP50-95=0.927030
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.37G     0.7703     0.5739       1.05         59        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:142.3ss
# train_epoch_end=14/50
# train_epoch_end=14/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:585.6ss
#                    all       3000       8854      0.963      0.957       0.98      0.831
# epoch=14/50 P=0.962850 R=0.957380 mAP50=0.979860 mAP50-95=0.830700 train_box=0.770290 train_cls=0.573850 train_dfl=1.050330 val_box=0.569490 val_cls=0.394900 val_dfl=0.923410
# epoch=14/50 P=0.962850 R=0.957380 mAP50=0.979860 mAP50-95=0.830700 train_box=0.770290 train_cls=0.573850 train_dfl=1.050330 val_box=0.569490 val_cls=0.394900 val_dfl=0.923410
#   class_id=0 class_name=лицо P=0.941661 R=0.909187 mAP50=0.954903 mAP50-95=0.694416
#   class_id=0 class_name= P=0.941661 R=0.909187 mAP50=0.954903 mAP50-95=0.694416
#   class_id=1 class_name=голова P=0.971978 R=0.978341 mAP50=0.991264 mAP50-95=0.888697
#   class_id=1 class_name= P=0.971978 R=0.978341 mAP50=0.991264 mAP50-95=0.888697
#   class_id=2 class_name=персонаж P=0.974925 R=0.984624 mAP50=0.993421 mAP50-95=0.908999
#   class_id=2 class_name= P=0.974925 R=0.984624 mAP50=0.993421 mAP50-95=0.908999
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.37G     0.7614      0.563      1.045         48        640: 100% ━━━━━━━━━━━━ 188/188 3.0s/it 9:162.3ss
# train_epoch_end=15/50
# train_epoch_end=15/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94

#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:525.5ss
#                    all       3000       8854       0.97      0.967      0.987      0.869
# epoch=20/50 P=0.969780 R=0.967220 mAP50=0.986700 mAP50-95=0.869280 train_box=0.721980 train_cls=0.515330 train_dfl=1.023700 val_box=0.493530 val_cls=0.340260 val_dfl=0.883310
# epoch=20/50 P=0.969780 R=0.967220 mAP50=0.986700 mAP50-95=0.869280 train_box=0.721980 train_cls=0.515330 train_dfl=1.023700 val_box=0.493530 val_cls=0.340260 val_dfl=0.883310
#   class_id=0 class_name=лицо P=0.956097 R=0.923942 mAP50=0.971579 mAP50-95=0.752247
#   class_id=0 class_name= P=0.956097 R=0.923942 mAP50=0.971579 mAP50-95=0.752247
#   class_id=1 class_name=голова P=0.978111 R=0.982723 mAP50=0.993844 mAP50-95=0.911667
#   class_id=1 class_name= P=0.978111 R=0.982723 mAP50=0.993844 mAP50-95=0.911667
#   class_id=2 class_name=персонаж P=0.975119 R=0.995002 mAP50=0.994666 mAP50-95=0.943937
#   class_id=2 class_name= P=0.975119 R=0.995002 mAP50=0.994666 mAP50-95=0.943937
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      2.37G     0.7289     0.5216      1.032         48        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:142.3ss
# train_epoch_end=21/50
# train_epoch_end=21/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.6s/it 8:505.5ss
#                    all       3000       8854      0.974      0.969      0.986      0.863
# epoch=21/50 P=0.973540 R=0.968850 mAP50=0.985540 mAP50-95=0.863440 train_box=0.728880 train_cls=0.521580 train_dfl=1.032190 val_box=0.513320 val_cls=0.345350 val_dfl=0.890100
# epoch=21/50 P=0.973540 R=0.968850 mAP50=0.985540 mAP50-95=0.863440 train_box=0.728880 train_cls=0.521580 train_dfl=1.032190 val_box=0.513320 val_cls=0.345350 val_dfl=0.890100
#   class_id=0 class_name=лицо P=0.950248 R=0.929874 mAP50=0.968242 mAP50-95=0.741752
#   class_id=0 class_name= P=0.950248 R=0.929874 mAP50=0.968242 mAP50-95=0.741752
#   class_id=1 class_name=голова P=0.985157 R=0.986338 mAP50=0.994234 mAP50-95=0.911796
#   class_id=1 class_name= P=0.985157 R=0.986338 mAP50=0.994234 mAP50-95=0.911796
#   class_id=2 class_name=персонаж P=0.985217 R=0.990337 mAP50=0.994147 mAP50-95=0.936772
#   class_id=2 class_name= P=0.985217 R=0.990337 mAP50=0.994147 mAP50-95=0.936772
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      2.37G     0.7113     0.5119      1.019         44        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:122.3ss
# train_epoch_end=22/50
# train_epoch_end=22/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.6s/it 8:515.5ss
#                    all       3000       8854      0.973      0.964      0.985      0.869
# epoch=22/50 P=0.973110 R=0.964080 mAP50=0.985060 mAP50-95=0.868690 train_box=0.711280 train_cls=0.511870 train_dfl=1.019320 val_box=0.496990 val_cls=0.333680 val_dfl=0.888320
# epoch=22/50 P=0.973110 R=0.964080 mAP50=0.985060 mAP50-95=0.868690 train_box=0.711280 train_cls=0.511870 train_dfl=1.019320 val_box=0.496990 val_cls=0.333680 val_dfl=0.888320
#   class_id=0 class_name=лицо P=0.953319 R=0.916552 mAP50=0.966367 mAP50-95=0.754243
#   class_id=0 class_name= P=0.953319 R=0.916552 mAP50=0.966367 mAP50-95=0.754243
#   class_id=1 class_name=голова P=0.981093 R=0.985671 mAP50=0.994199 mAP50-95=0.911677
#   class_id=1 class_name= P=0.981093 R=0.985671 mAP50=0.994199 mAP50-95=0.911677
#   class_id=2 class_name=персонаж P=0.984916 R=0.990003 mAP50=0.994608 mAP50-95=0.940136
#   class_id=2 class_name= P=0.984916 R=0.990003 mAP50=0.994608 mAP50-95=0.940136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      2.37G     0.7223     0.5137      1.025         61        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:142.3ss
# train_epoch_end=23/50
# train_epoch_end=23/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:525.5ss
#                    all       3000       8854      0.971      0.965      0.985      0.852
# epoch=23/50 P=0.970570 R=0.964810 mAP50=0.984810 mAP50-95=0.851620 train_box=0.722260 train_cls=0.513680 train_dfl=1.024810 val_box=0.534340 val_cls=0.350740 val_dfl=0.904640
# epoch=23/50 P=0.970570 R=0.964810 mAP50=0.984810 mAP50-95=0.851620 train_box=0.722260 train_cls=0.513680 train_dfl=1.024810 val_box=0.534340 val_cls=0.350740 val_dfl=0.904640
#   class_id=0 class_name=лицо P=0.955638 R=0.933731 mAP50=0.967982 mAP50-95=0.734557
#   class_id=0 class_name= P=0.955638 R=0.933731 mAP50=0.967982 mAP50-95=0.734557
#   class_id=1 class_name=голова P=0.984869 R=0.976028 mAP50=0.992623 mAP50-95=0.898653
#   class_id=1 class_name= P=0.984869 R=0.976028 mAP50=0.992623 mAP50-95=0.898653
#   class_id=2 class_name=персонаж P=0.971215 R=0.984672 mAP50=0.993811 mAP50-95=0.921641
#   class_id=2 class_name= P=0.971215 R=0.984672 mAP50=0.993811 mAP50-95=0.921641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      2.37G     0.7047     0.5059      1.024         37        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:142.4ss
# train_epoch_end=24/50
# train_epoch_end=24/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:525.5ss
#                    all       3000       8854      0.977      0.972      0.987      0.877
# epoch=24/50 P=0.976690 R=0.971580 mAP50=0.987490 mAP50-95=0.877140 train_box=0.704750 train_cls=0.505930 train_dfl=1.024310 val_box=0.478320 val_cls=0.324210 val_dfl=0.881760
# epoch=24/50 P=0.976690 R=0.971580 mAP50=0.987490 mAP50-95=0.877140 train_box=0.704750 train_cls=0.505930 train_dfl=1.024310 val_box=0.478320 val_cls=0.324210 val_dfl=0.881760
#   class_id=0 class_name=лицо P=0.962673 R=0.931409 mAP50=0.973349 mAP50-95=0.764500
#   class_id=0 class_name= P=0.962673 R=0.931409 mAP50=0.973349 mAP50-95=0.764500
#   class_id=1 class_name=голова P=0.979468 R=0.987671 mAP50=0.994336 mAP50-95=0.920046
#   class_id=1 class_name= P=0.979468 R=0.987671 mAP50=0.994336 mAP50-95=0.920046
#   class_id=2 class_name=персонаж P=0.987921 R=0.995668 mAP50=0.994776 mAP50-95=0.946871
#   class_id=2 class_name= P=0.987921 R=0.995668 mAP50=0.994776 mAP50-95=0.946871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      2.37G     0.6997     0.4947      1.018         44        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:132.1ss
# train_epoch_end=25/50
# train_epoch_end=25/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:525.5ss
#                    all       3000       8854      0.969      0.969      0.985      0.875
# epoch=25/50 P=0.968580 R=0.969150 mAP50=0.985330 mAP50-95=0.874550 train_box=0.699680 train_cls=0.494670 train_dfl=1.017720 val_box=0.480970 val_cls=0.323010 val_dfl=0.877220
# epoch=25/50 P=0.968580 R=0.969150 mAP50=0.985330 mAP50-95=0.874550 train_box=0.699680 train_cls=0.494670 train_dfl=1.017720 val_box=0.480970 val_cls=0.323010 val_dfl=0.877220
#   class_id=0 class_name=лицо P=0.955666 R=0.922113 mAP50=0.968320 mAP50-95=0.757069
#   class_id=0 class_name= P=0.955666 R=0.922113 mAP50=0.968320 mAP50-95=0.757069
#   class_id=1 class_name=голова P=0.973760 R=0.989670 mAP50=0.993354 mAP50-95=0.919106
#   class_id=1 class_name= P=0.973760 R=0.989670 mAP50=0.993354 mAP50-95=0.919106
#   class_id=2 class_name=персонаж P=0.976315 R=0.995668 mAP50=0.994315 mAP50-95=0.947473
#   class_id=2 class_name= P=0.976315 R=0.995668 mAP50=0.994315 mAP50-95=0.947473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.37G     0.7007     0.5014      1.019         41        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:122.4ss
# train_epoch_end=26/50
# train_epoch_end=26/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:555.5ss
#                    all       3000       8854      0.977      0.969      0.987      0.876
# epoch=26/50 P=0.976830 R=0.968760 mAP50=0.986570 mAP50-95=0.876080 train_box=0.700700 train_cls=0.501350 train_dfl=1.018720 val_box=0.478710 val_cls=0.321550 val_dfl=0.881060
# epoch=26/50 P=0.976830 R=0.968760 mAP50=0.986570 mAP50-95=0.876080 train_box=0.700700 train_cls=0.501350 train_dfl=1.018720 val_box=0.478710 val_cls=0.321550 val_dfl=0.881060
#   class_id=0 class_name=лицо P=0.960164 R=0.929631 mAP50=0.971733 mAP50-95=0.763359
#   class_id=0 class_name= P=0.960164 R=0.929631 mAP50=0.971733 mAP50-95=0.763359
#   class_id=1 class_name=голова P=0.981630 R=0.986005 mAP50=0.993291 mAP50-95=0.919091
#   class_id=1 class_name= P=0.981630 R=0.986005 mAP50=0.993291 mAP50-95=0.919091
#   class_id=2 class_name=персонаж P=0.988693 R=0.990644 mAP50=0.994698 mAP50-95=0.945802
#   class_id=2 class_name= P=0.988693 R=0.990644 mAP50=0.994698 mAP50-95=0.945802
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      2.37G     0.6893     0.4886      1.015         59        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:122.2ss
# train_epoch_end=27/50
# train_epoch_end=27/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.6s/it 8:505.5ss
#                    all       3000       8854       0.98      0.971      0.987       0.88
# epoch=27/50 P=0.979810 R=0.971360 mAP50=0.987300 mAP50-95=0.879940 train_box=0.689340 train_cls=0.488590 train_dfl=1.014500 val_box=0.477840 val_cls=0.312520 val_dfl=0.875650
# epoch=27/50 P=0.979810 R=0.971360 mAP50=0.987300 mAP50-95=0.879940 train_box=0.689340 train_cls=0.488590 train_dfl=1.014500 val_box=0.477840 val_cls=0.312520 val_dfl=0.875650
#   class_id=0 class_name=лицо P=0.960447 R=0.936551 mAP50=0.973062 mAP50-95=0.766333
#   class_id=0 class_name= P=0.960447 R=0.936551 mAP50=0.973062 mAP50-95=0.766333
#   class_id=1 class_name=голова P=0.986306 R=0.984020 mAP50=0.994001 mAP50-95=0.920738
#   class_id=1 class_name= P=0.986306 R=0.984020 mAP50=0.994001 mAP50-95=0.920738
#   class_id=2 class_name=персонаж P=0.992675 R=0.993497 mAP50=0.994825 mAP50-95=0.952738
#   class_id=2 class_name= P=0.992675 R=0.993497 mAP50=0.994825 mAP50-95=0.952738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      2.37G     0.6892     0.4825      1.013         45        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:092.2ss
# train_epoch_end=28/50
# train_epoch_end=28/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:525.5ss
#                    all       3000       8854      0.974      0.972      0.986      0.882
# epoch=28/50 P=0.974150 R=0.971530 mAP50=0.986420 mAP50-95=0.882260 train_box=0.689170 train_cls=0.482460 train_dfl=1.013480 val_box=0.469260 val_cls=0.315090 val_dfl=0.876220
# epoch=28/50 P=0.974150 R=0.971530 mAP50=0.986420 mAP50-95=0.882260 train_box=0.689170 train_cls=0.482460 train_dfl=1.013480 val_box=0.469260 val_cls=0.315090 val_dfl=0.876220
#   class_id=0 class_name=лицо P=0.948326 R=0.939491 mAP50=0.970473 mAP50-95=0.767690
#   class_id=0 class_name= P=0.948326 R=0.939491 mAP50=0.970473 mAP50-95=0.767690
#   class_id=1 class_name=голова P=0.987318 R=0.985772 mAP50=0.994302 mAP50-95=0.926421
#   class_id=1 class_name= P=0.987318 R=0.985772 mAP50=0.994302 mAP50-95=0.926421
#   class_id=2 class_name=персонаж P=0.986818 R=0.989337 mAP50=0.994499 mAP50-95=0.952675
#   class_id=2 class_name= P=0.986818 R=0.989337 mAP50=0.994499 mAP50-95=0.952675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      2.37G     0.6707     0.4726      1.003         51        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:122.3ss
# train_epoch_end=29/50
# train_epoch_end=29/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.6s/it 8:515.5ss
#                    all       3000       8854       0.98      0.973      0.988       0.89
# epoch=29/50 P=0.980090 R=0.972690 mAP50=0.988420 mAP50-95=0.890310 train_box=0.670670 train_cls=0.472650 train_dfl=1.002640 val_box=0.450670 val_cls=0.298380 val_dfl=0.867180
# epoch=29/50 P=0.980090 R=0.972690 mAP50=0.988420 mAP50-95=0.890310 train_box=0.670670 train_cls=0.472650 train_dfl=1.002640 val_box=0.450670 val_cls=0.298380 val_dfl=0.867180
#   class_id=0 class_name=лицо P=0.962377 R=0.933731 mAP50=0.975868 mAP50-95=0.779852
#   class_id=0 class_name= P=0.962377 R=0.933731 mAP50=0.975868 mAP50-95=0.779852
#   class_id=1 class_name=голова P=0.986757 R=0.989004 mAP50=0.994590 mAP50-95=0.932773
#   class_id=1 class_name= P=0.986757 R=0.989004 mAP50=0.994590 mAP50-95=0.932773
#   class_id=2 class_name=персонаж P=0.991131 R=0.995335 mAP50=0.994812 mAP50-95=0.958295
#   class_id=2 class_name= P=0.991131 R=0.995335 mAP50=0.994812 mAP50-95=0.958295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      2.37G     0.6726     0.4736      1.004         43        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:122.3ss
# train_epoch_end=30/50
# train_epoch_end=30/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:515.5ss
#                    all       3000       8854      0.977      0.975      0.988      0.893
# epoch=30/50 P=0.977420 R=0.975130 mAP50=0.988160 mAP50-95=0.892710 train_box=0.672620 train_cls=0.473640 train_dfl=1.003850 val_box=0.441540 val_cls=0.293940 val_dfl=0.862210
# epoch=30/50 P=0.977420 R=0.975130 mAP50=0.988160 mAP50-95=0.892710 train_box=0.672620 train_cls=0.473640 train_dfl=1.003850 val_box=0.441540 val_cls=0.293940 val_dfl=0.862210
#   class_id=0 class_name=лицо P=0.961455 R=0.940393 mAP50=0.975252 mAP50-95=0.787153
#   class_id=0 class_name= P=0.961455 R=0.940393 mAP50=0.975252 mAP50-95=0.787153
#   class_id=1 class_name=голова P=0.984972 R=0.988337 mAP50=0.994476 mAP50-95=0.932901
#   class_id=1 class_name= P=0.984972 R=0.988337 mAP50=0.994476 mAP50-95=0.932901
#   class_id=2 class_name=персонаж P=0.985829 R=0.996668 mAP50=0.994741 mAP50-95=0.958083
#   class_id=2 class_name= P=0.985829 R=0.996668 mAP50=0.994741 mAP50-95=0.958083
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      2.37G     0.6851      0.477      1.007         31        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:122.3ss
# train_epoch_end=31/50
# train_epoch_end=31/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.6s/it 8:515.5ss
#                    all       3000       8854      0.978      0.972      0.989      0.886
# epoch=31/50 P=0.977570 R=0.972400 mAP50=0.988570 mAP50-95=0.886050 train_box=0.685120 train_cls=0.476980 train_dfl=1.006700 val_box=0.457270 val_cls=0.303270 val_dfl=0.866690
# epoch=31/50 P=0.977570 R=0.972400 mAP50=0.988570 mAP50-95=0.886050 train_box=0.685120 train_cls=0.476980 train_dfl=1.006700 val_box=0.457270 val_cls=0.303270 val_dfl=0.866690
#   class_id=0 class_name=лицо P=0.959956 R=0.935484 mAP50=0.976378 mAP50-95=0.776344
#   class_id=0 class_name= P=0.959956 R=0.935484 mAP50=0.976378 mAP50-95=0.776344
#   class_id=1 class_name=голова P=0.981398 R=0.989670 mAP50=0.994562 mAP50-95=0.925819
#   class_id=1 class_name= P=0.981398 R=0.989670 mAP50=0.994562 mAP50-95=0.925819
#   class_id=2 class_name=персонаж P=0.991342 R=0.992055 mAP50=0.994774 mAP50-95=0.955976
#   class_id=2 class_name= P=0.991342 R=0.992055 mAP50=0.994774 mAP50-95=0.955976
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.37G     0.6636     0.4649     0.9959         60        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:142.3ss
# train_epoch_end=32/50
# train_epoch_end=32/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:525.5ss
#                    all       3000       8854      0.978      0.971      0.988      0.879
# ...
#       41/50      2.37G     0.5296     0.3322     0.9175         23        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:102.3ss
# train_epoch_end=41/50
# train_epoch_end=41/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:575.5ss
#                    all       3000       8854      0.983       0.98      0.991      0.906
# epoch=41/50 P=0.983040 R=0.979840 mAP50=0.990580 mAP50-95=0.906270 train_box=0.529590 train_cls=0.332250 train_dfl=0.917470 val_box=0.407520 val_cls=0.262980 val_dfl=0.844310
# epoch=41/50 P=0.983040 R=0.979840 mAP50=0.990580 mAP50-95=0.906270 train_box=0.529590 train_cls=0.332250 train_dfl=0.917470 val_box=0.407520 val_cls=0.262980 val_dfl=0.844310
#   class_id=0 class_name=лицо P=0.966136 R=0.949509 mAP50=0.982052 mAP50-95=0.807594
#   class_id=0 class_name= P=0.966136 R=0.949509 mAP50=0.982052 mAP50-95=0.807594
#   class_id=1 class_name=голова P=0.989893 R=0.993002 mAP50=0.994747 mAP50-95=0.943770
#   class_id=1 class_name= P=0.989893 R=0.993002 mAP50=0.994747 mAP50-95=0.943770
#   class_id=2 class_name=персонаж P=0.993085 R=0.997001 mAP50=0.994935 mAP50-95=0.967440
#   class_id=2 class_name= P=0.993085 R=0.997001 mAP50=0.994935 mAP50-95=0.967440
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.37G     0.5274     0.3239     0.9146         22        640: 100% ━━━━━━━━━━━━ 188/188 3.0s/it 9:202.4ss
# train_epoch_end=42/50
# train_epoch_end=42/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.8s/it 9:015.6ss
#                    all       3000       8854      0.982      0.981      0.991      0.904
# epoch=42/50 P=0.981970 R=0.981460 mAP50=0.990540 mAP50-95=0.904210 train_box=0.527380 train_cls=0.323880 train_dfl=0.914640 val_box=0.410200 val_cls=0.261050 val_dfl=0.844870
# epoch=42/50 P=0.981970 R=0.981460 mAP50=0.990540 mAP50-95=0.904210 train_box=0.527380 train_cls=0.323880 train_dfl=0.914640 val_box=0.410200 val_cls=0.261050 val_dfl=0.844870
#   class_id=0 class_name=лицо P=0.963510 R=0.953609 mAP50=0.982023 mAP50-95=0.807412
#   class_id=0 class_name= P=0.963510 R=0.953609 mAP50=0.982023 mAP50-95=0.807412
#   class_id=1 class_name=голова P=0.989378 R=0.993205 mAP50=0.994721 mAP50-95=0.941197
#   class_id=1 class_name= P=0.989378 R=0.993205 mAP50=0.994721 mAP50-95=0.941197
#   class_id=2 class_name=персонаж P=0.993034 R=0.997565 mAP50=0.994861 mAP50-95=0.964032
#   class_id=2 class_name= P=0.993034 R=0.997565 mAP50=0.994861 mAP50-95=0.964032
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      2.37G     0.5295      0.321     0.9149         24        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:092.3ss
# train_epoch_end=43/50
# train_epoch_end=43/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:575.5ss
#                    all       3000       8854      0.985      0.982      0.991      0.906
# epoch=43/50 P=0.984890 R=0.981570 mAP50=0.991200 mAP50-95=0.905790 train_box=0.529460 train_cls=0.320960 train_dfl=0.914940 val_box=0.409820 val_cls=0.258380 val_dfl=0.843700
# epoch=43/50 P=0.984890 R=0.981570 mAP50=0.991200 mAP50-95=0.905790 train_box=0.529460 train_cls=0.320960 train_dfl=0.914940 val_box=0.409820 val_cls=0.258380 val_dfl=0.843700
#   class_id=0 class_name=лицо P=0.971526 R=0.953717 mAP50=0.983922 mAP50-95=0.810152
#   class_id=0 class_name= P=0.971526 R=0.953717 mAP50=0.983922 mAP50-95=0.810152
#   class_id=1 class_name=голова P=0.990130 R=0.993002 mAP50=0.994704 mAP50-95=0.942467
#   class_id=1 class_name= P=0.990130 R=0.993002 mAP50=0.994704 mAP50-95=0.942467
#   class_id=2 class_name=персонаж P=0.993025 R=0.998001 mAP50=0.994959 mAP50-95=0.964764
#   class_id=2 class_name= P=0.993025 R=0.998001 mAP50=0.994959 mAP50-95=0.964764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.37G     0.5214     0.3162     0.9152         22        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:142.2ss
# train_epoch_end=44/50
# train_epoch_end=44/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:575.5ss
#                    all       3000       8854      0.986      0.983      0.991      0.911
# epoch=44/50 P=0.986190 R=0.982750 mAP50=0.991020 mAP50-95=0.910590 train_box=0.521420 train_cls=0.316170 train_dfl=0.915220 val_box=0.397730 val_cls=0.251400 val_dfl=0.838270
# epoch=44/50 P=0.986190 R=0.982750 mAP50=0.991020 mAP50-95=0.910590 train_box=0.521420 train_cls=0.316170 train_dfl=0.915220 val_box=0.397730 val_cls=0.251400 val_dfl=0.838270
#   class_id=0 class_name=лицо P=0.966386 R=0.957652 mAP50=0.983168 mAP50-95=0.814312
#   class_id=0 class_name= P=0.966386 R=0.957652 mAP50=0.983168 mAP50-95=0.814312
#   class_id=1 class_name=голова P=0.995322 R=0.992593 mAP50=0.994901 mAP50-95=0.947822
#   class_id=1 class_name= P=0.995322 R=0.992593 mAP50=0.994901 mAP50-95=0.947822
#   class_id=2 class_name=персонаж P=0.996848 R=0.998001 mAP50=0.994980 mAP50-95=0.969641
#   class_id=2 class_name= P=0.996848 R=0.998001 mAP50=0.994980 mAP50-95=0.969641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.37G     0.5134     0.3085     0.9076         24        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:132.3ss
# train_epoch_end=45/50
# train_epoch_end=45/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:575.5ss
#                    all       3000       8854      0.989      0.981      0.991      0.911
# epoch=45/50 P=0.989350 R=0.980840 mAP50=0.990660 mAP50-95=0.910810 train_box=0.513420 train_cls=0.308500 train_dfl=0.907550 val_box=0.395080 val_cls=0.249620 val_dfl=0.838610
# epoch=45/50 P=0.989350 R=0.980840 mAP50=0.990660 mAP50-95=0.910810 train_box=0.513420 train_cls=0.308500 train_dfl=0.907550 val_box=0.395080 val_cls=0.249620 val_dfl=0.838610
#   class_id=0 class_name=лицо P=0.976668 R=0.949509 mAP50=0.982203 mAP50-95=0.813599
#   class_id=0 class_name= P=0.976668 R=0.949509 mAP50=0.982203 mAP50-95=0.813599
#   class_id=1 class_name=голова P=0.994389 R=0.994335 mAP50=0.994792 mAP50-95=0.947912
#   class_id=1 class_name= P=0.994389 R=0.994335 mAP50=0.994792 mAP50-95=0.947912
#   class_id=2 class_name=персонаж P=0.997006 R=0.998679 mAP50=0.994997 mAP50-95=0.970934
#   class_id=2 class_name= P=0.997006 R=0.998679 mAP50=0.994997 mAP50-95=0.970934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      2.37G     0.5185     0.3165      0.918         24        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:122.3ss
# train_epoch_end=46/50
# train_epoch_end=46/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:545.5ss
#                    all       3000       8854      0.987      0.983      0.991      0.916
# epoch=46/50 P=0.986900 R=0.982610 mAP50=0.991100 mAP50-95=0.915730 train_box=0.518540 train_cls=0.316520 train_dfl=0.917980 val_box=0.382790 val_cls=0.243340 val_dfl=0.834860
# epoch=46/50 P=0.986900 R=0.982610 mAP50=0.991100 mAP50-95=0.915730 train_box=0.518540 train_cls=0.316520 train_dfl=0.917980 val_box=0.382790 val_cls=0.243340 val_dfl=0.834860
#   class_id=0 class_name=лицо P=0.969376 R=0.954504 mAP50=0.983370 mAP50-95=0.822097
#   class_id=0 class_name= P=0.969376 R=0.954504 mAP50=0.983370 mAP50-95=0.822097
#   class_id=1 class_name=голова P=0.994383 R=0.994668 mAP50=0.994935 mAP50-95=0.953191
#   class_id=1 class_name= P=0.994383 R=0.994668 mAP50=0.994935 mAP50-95=0.953191
#   class_id=2 class_name=персонаж P=0.996946 R=0.998667 mAP50=0.994993 mAP50-95=0.971916
#   class_id=2 class_name= P=0.996946 R=0.998667 mAP50=0.994993 mAP50-95=0.971916
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      2.37G     0.5016     0.3022      0.905         24        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:092.2ss
# train_epoch_end=47/50
# train_epoch_end=47/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:555.5ss
#                    all       3000       8854      0.988      0.982      0.991      0.914
# epoch=47/50 P=0.988050 R=0.982130 mAP50=0.991190 mAP50-95=0.914350 train_box=0.501630 train_cls=0.302210 train_dfl=0.904990 val_box=0.387630 val_cls=0.244220 val_dfl=0.835020
# epoch=47/50 P=0.988050 R=0.982130 mAP50=0.991190 mAP50-95=0.914350 train_box=0.501630 train_cls=0.302210 train_dfl=0.904990 val_box=0.387630 val_cls=0.244220 val_dfl=0.835020
#   class_id=0 class_name=лицо P=0.973139 R=0.952707 mAP50=0.983649 mAP50-95=0.819344
#   class_id=0 class_name= P=0.973139 R=0.952707 mAP50=0.983649 mAP50-95=0.819344
#   class_id=1 class_name=голова P=0.995305 R=0.994668 mAP50=0.994946 mAP50-95=0.951845
#   class_id=1 class_name= P=0.995305 R=0.994668 mAP50=0.994946 mAP50-95=0.951845
#   class_id=2 class_name=персонаж P=0.995698 R=0.999000 mAP50=0.994987 mAP50-95=0.971851
#   class_id=2 class_name= P=0.995698 R=0.999000 mAP50=0.994987 mAP50-95=0.971851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      2.37G      0.499     0.3003     0.9011         23        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:112.2ss
# train_epoch_end=48/50
# train_epoch_end=48/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:535.5ss
#                    all       3000       8854      0.987      0.984      0.991      0.917
# epoch=48/50 P=0.987180 R=0.984430 mAP50=0.991370 mAP50-95=0.917120 train_box=0.499050 train_cls=0.300310 train_dfl=0.901140 val_box=0.378990 val_cls=0.238650 val_dfl=0.831590
# epoch=48/50 P=0.987180 R=0.984430 mAP50=0.991370 mAP50-95=0.917120 train_box=0.499050 train_cls=0.300310 train_dfl=0.901140 val_box=0.378990 val_cls=0.238650 val_dfl=0.831590
#   class_id=0 class_name=лицо P=0.967652 R=0.958976 mAP50=0.984141 mAP50-95=0.827300
#   class_id=0 class_name= P=0.967652 R=0.958976 mAP50=0.984141 mAP50-95=0.827300
#   class_id=1 class_name=голова P=0.996995 R=0.994966 mAP50=0.994966 mAP50-95=0.951549
#   class_id=1 class_name= P=0.996995 R=0.994966 mAP50=0.994966 mAP50-95=0.951549
#   class_id=2 class_name=персонаж P=0.996888 R=0.999334 mAP50=0.994997 mAP50-95=0.972522
#   class_id=2 class_name= P=0.996888 R=0.999334 mAP50=0.994997 mAP50-95=0.972522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.37G     0.5042     0.2987     0.9049         23        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:102.3ss
# train_epoch_end=49/50
# train_epoch_end=49/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:525.5ss
#                    all       3000       8854      0.987      0.984      0.992      0.916
# epoch=49/50 P=0.987180 R=0.983880 mAP50=0.991530 mAP50-95=0.915920 train_box=0.504250 train_cls=0.298750 train_dfl=0.904930 val_box=0.379880 val_cls=0.238020 val_dfl=0.832400
# epoch=49/50 P=0.987180 R=0.983880 mAP50=0.991530 mAP50-95=0.915920 train_box=0.504250 train_cls=0.298750 train_dfl=0.904930 val_box=0.379880 val_cls=0.238020 val_dfl=0.832400
#   class_id=0 class_name=лицо P=0.968131 R=0.958626 mAP50=0.984634 mAP50-95=0.822452
#   class_id=0 class_name= P=0.968131 R=0.958626 mAP50=0.984634 mAP50-95=0.822452
#   class_id=1 class_name=голова P=0.995772 R=0.994002 mAP50=0.994956 mAP50-95=0.952718
#   class_id=1 class_name= P=0.995772 R=0.994002 mAP50=0.994956 mAP50-95=0.952718
#   class_id=2 class_name=персонаж P=0.997640 R=0.999000 mAP50=0.994993 mAP50-95=0.972579
#   class_id=2 class_name= P=0.997640 R=0.999000 mAP50=0.994993 mAP50-95=0.972579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.37G     0.5024     0.3004      0.906         24        640: 100% ━━━━━━━━━━━━ 188/188 2.9s/it 9:122.3ss
# train_epoch_end=50/50
# train_epoch_end=50/50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:525.5ss
#                    all       3000       8854       0.99      0.983      0.992      0.917
# epoch=50/50 P=0.989810 R=0.982810 mAP50=0.991650 mAP50-95=0.917040 train_box=0.502410 train_cls=0.300380 train_dfl=0.906030 val_box=0.377090 val_cls=0.236440 val_dfl=0.831860
# epoch=50/50 P=0.989810 R=0.982810 mAP50=0.991650 mAP50-95=0.917040 train_box=0.502410 train_cls=0.300380 train_dfl=0.906030 val_box=0.377090 val_cls=0.236440 val_dfl=0.831860
#   class_id=0 class_name=лицо P=0.975950 R=0.955119 mAP50=0.985004 mAP50-95=0.826061
#   class_id=0 class_name= P=0.975950 R=0.955119 mAP50=0.985004 mAP50-95=0.826061
#   class_id=1 class_name=голова P=0.996660 R=0.994306 mAP50=0.994949 mAP50-95=0.953469
#   class_id=1 class_name= P=0.996660 R=0.994306 mAP50=0.994949 mAP50-95=0.953469
#   class_id=2 class_name=персонаж P=0.996808 R=0.999000 mAP50=0.994993 mAP50-95=0.971603
#   class_id=2 class_name= P=0.996808 R=0.999000 mAP50=0.994993 mAP50-95=0.971603
#
# 50 epochs completed in 15.121 hours.
# Optimizer stripped from E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\runs\train\weights\last.pt, 5.5MB
# Optimizer stripped from E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\runs\train\weights\best.pt, 5.5MB
#
# Validating E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\runs\train\weights\best.pt...
# Ultralytics 8.3.245  Python-3.10.19 torch-2.11.0.dev20251231+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Ti, 16311MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.7s/it 8:565.6ss
#                    all       3000       8854      0.987      0.984      0.991      0.917
#                          2849       2852      0.967      0.959      0.984      0.827
#                        2999       3001      0.997      0.995      0.995      0.951
#                      3000       3001      0.997      0.999      0.995      0.973
# Speed: 0.7ms preprocess, 3.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to E:\SosedTemporary\WorkingSpace\Narabotki\26-05-14_1\yolo11n_3000_full_train\yolo_dataset_1_0_3\runs\train
# epoch=50/50 P=0.989810 R=0.982810 mAP50=0.991650 mAP50-95=0.917040 train_box=0.502410 train_cls=0.300380 train_dfl=0.906030 val_box=0.377090 val_cls=0.236440 val_dfl=0.831860
# epoch=50/50 P=0.989810 R=0.982810 mAP50=0.991650 mAP50-95=0.917040 train_box=0.502410 train_cls=0.300380 train_dfl=0.906030 val_box=0.377090 val_cls=0.236440 val_dfl=0.831860
#   class_id=0 class_name=лицо P=0.967114 R=0.958626 mAP50=0.984134 mAP50-95=0.827323
#   class_id=0 class_name= P=0.967114 R=0.958626 mAP50=0.984134 mAP50-95=0.827323
#   class_id=1 class_name=голова P=0.996995 R=0.994999 mAP50=0.994966 mAP50-95=0.951464
#   class_id=1 class_name= P=0.996995 R=0.994999 mAP50=0.994966 mAP50-95=0.951464
#   class_id=2 class_name=персонаж P=0.996875 R=0.999334 mAP50=0.994997 mAP50-95=0.972507
#   class_id=2 class_name= P=0.996875 R=0.999334 mAP50=0.994997 mAP50-95=0.972507
# {'save_dir': 'E:\\SosedTemporary\\WorkingSpace\\Narabotki\\26-05-14_1\\yolo11n_3000_full_train\\yolo_dataset_1_0_3\\runs\\train',
#  'best_weights': 'E:\\SosedTemporary\\WorkingSpace\\Narabotki\\26-05-14_1\\yolo11n_3000_full_train\\yolo_dataset_1_0_3\\runs\\train\\weights\\best.pt',
#  'last_weights': 'E:\\SosedTemporary\\WorkingSpace\\Narabotki\\26-05-14_1\\yolo11n_3000_full_train\\yolo_dataset_1_0_3\\runs\\train\\weights\\last.pt',
#  'results_csv': 'E:\\SosedTemporary\\WorkingSpace\\Narabotki\\26-05-14_1\\yolo11n_3000_full_train\\yolo_dataset_1_0_3\\runs\\train\\results.csv',
#  'metrics_txt': 'E:\\SosedTemporary\\WorkingSpace\\Narabotki\\26-05-14_1\\yolo11n_3000_full_train\\yolo_dataset_1_0_3\\metrics_log.txt'}
