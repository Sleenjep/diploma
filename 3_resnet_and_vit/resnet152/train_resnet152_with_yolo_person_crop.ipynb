# %%
import os
import json
import time
from pathlib import Path

import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from tqdm.auto import tqdm

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from ultralytics import YOLO

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"

ROOT = Path.cwd()
DATASET_DIR = ROOT / "dataset"
YOLO_WEIGHTS = ROOT / "best.pt"
LABELS_FILE = ROOT / "4_1_features_transformation_and_merging.xlsx"
OUTPUT_DIR = ROOT / "resnet152_person_output"
PERSON_CROPS_DIR = ROOT / "crops" / "person_crops"
FACE_CROPS_DIR = ROOT / "crops" / "face_crops"
HEAD_CROPS_DIR = ROOT / "crops" / "head_crops"
PROGRESS_DIR = OUTPUT_DIR / "progress_json"
BACKBONE = "resnet152"
EPOCHS = 5
BATCH_SIZE = 16
LR = 1e-4
IMG_SIZE = 224
TEST_SIZE = 0.1
VAL_SIZE = 0.1
SEED = 42
YOLO_CONF = 0.25
YOLO_IMGSZ = 640
REUSE_EXISTING_CROPS = False
CROP_STAGE_MODE = "auto"
ALLOW_YOLO_AUTOFILL = True
VAL_COMPUTE_PER_FEATURE_F1 = False
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

preview_df = pd.read_excel(LABELS_FILE)
print({"rows": int(preview_df.shape[0]), "cols": int(preview_df.shape[1])})
preview_df.head()

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
PERSON_CROPS_DIR.mkdir(parents=True, exist_ok=True)
FACE_CROPS_DIR.mkdir(parents=True, exist_ok=True)
HEAD_CROPS_DIR.mkdir(parents=True, exist_ok=True)
PROGRESS_DIR.mkdir(parents=True, exist_ok=True)
(PROGRESS_DIR / "epochs").mkdir(parents=True, exist_ok=True)

torch.manual_seed(SEED)
np.random.seed(SEED)
# Out:
# {'rows': 8422, 'cols': 147}

# %% [markdown]
# ## B. Labels, features, and data split preparation

# %%
def read_labels_table(path: Path) -> pd.DataFrame:
    suffix = path.suffix.lower()
    if suffix in {".xlsx", ".xls", ".xlsm"}:
        return pd.read_excel(path)
    if suffix in {".csv", ".txt"}:
        return pd.read_csv(path)


def find_image_column(df: pd.DataFrame) -> str:
    lower_to_orig = {str(c).lower(): str(c) for c in df.columns}
    candidates = ["image", "image_name", "filename", "file", "img", "image_id", "name", "path"]
    for c in candidates:
        if c in lower_to_orig:
            return lower_to_orig[c]
    for col in df.columns:
        s = df[col].astype(str).str.lower()
        if s.str.contains(".png", regex=False).any() or s.str.contains(".jpg", regex=False).any() or s.str.contains(".jpeg", regex=False).any():
            return str(col)


def select_target_columns(df: pd.DataFrame, image_col: str) -> list[str]:
    blocked_exact = {image_col.lower(), "split", "subset", "set"}
    blocked_partials = ["идентификатор", "identifier", "image", "img", "file", "filename", "path"]
    out = []
    for c in df.columns:
        cl = str(c).lower().strip()
        if cl in blocked_exact:
            continue
        if any(p in cl for p in blocked_partials):
            continue
        out.append(str(c))
    return out


def normalize_value(v):
    if pd.isna(v):
        return "__MISSING__"
    s = str(v).strip()
    if not s:
        return "__MISSING__"
    if s.lower() in {"nan", "none", "null"}:
        return "__MISSING__"
    return s


def infer_feature_type(labels):
    return "binary" if len(labels) <= 2 else "multiclass"


all_png = sorted(p for p in DATASET_DIR.rglob("*") if p.is_file() and p.suffix.lower() == ".png")
by_name = {p.name: p for p in all_png}
by_stem = {}
for p in all_png:
    if p.stem not in by_stem:
        by_stem[p.stem] = p


def resolve_image_path(value: str) -> Path | None:
    v = str(value).strip()
    if not v:
        return None
    p = Path(v)
    if p.exists() and p.is_file():
        return p
    name = Path(v).name
    if name in by_name:
        return by_name[name]
    stem = Path(name).stem
    if stem in by_stem:
        return by_stem[stem]
    return None


from feature_lists import full_image_person_features

df = read_labels_table(LABELS_FILE)
image_col = find_image_column(df)
all_candidate_target_cols = select_target_columns(df, image_col)
allowed_feature_set = set(full_image_person_features)
target_cols = [c for c in all_candidate_target_cols if c in allowed_feature_set]


print(
    f"Для person-crop обучения выбрано признаков из списка: {len(target_cols)} "
    f"(кандидатов до фильтрации: {len(all_candidate_target_cols)})"
)

df = df.dropna(subset=[image_col]).copy()
df["resolved_image"] = df[image_col].apply(resolve_image_path)
df = df[df["resolved_image"].notnull()].copy()

feature_infos_all = {}
for c in target_cols:
    vals = df[c].map(normalize_value)
    labels = sorted(vals.unique().tolist())
    if "__MISSING__" in labels:
        labels = ["__MISSING__"] + [x for x in labels if x != "__MISSING__"]
    label2id = {k: i for i, k in enumerate(labels)}
    id2label = {str(i): k for i, k in enumerate(labels)}
    counts = vals.value_counts(dropna=False).to_dict()
    missing_count = int(counts.get("__MISSING__", 0))
    feature_type = infer_feature_type(labels)
    feature_infos_all[c] = {
        "feature_type": feature_type,
        "num_labels": int(len(labels)),
        "label2id": label2id,
        "id2label": id2label,
        "counts": {str(k): int(v) for k, v in counts.items()},
        "has_missing": "__MISSING__" in label2id,
        "missing_count": missing_count,
    }
    print(
        f"Признак '{c}': тип={feature_type}, классов={len(labels)}, "
        f"есть_пропуски={'да' if '__MISSING__' in label2id else 'нет'}, "
        f"пропусков={missing_count}"
    )

target_cols = [c for c in target_cols if int(feature_infos_all[c]["num_labels"]) >= 2]
excluded_single_label = [c for c, v in feature_infos_all.items() if int(v["num_labels"]) < 2]
feature_infos = {c: feature_infos_all[c] for c in target_cols}
print(
    f"Признаков всего: {len(feature_infos_all)} | "
    f"исключено одно-классовых: {len(excluded_single_label)} | "
    f"итоговых признаков: {len(target_cols)}"
)


def encode_row(row):
    return [int(feature_infos[c]["label2id"][normalize_value(row[c])]) for c in target_cols]


df["encoded_targets"] = df.apply(encode_row, axis=1)


train_df, temp_df = train_test_split(df, test_size=VAL_SIZE + TEST_SIZE, random_state=SEED, shuffle=True)
val_ratio_in_temp = VAL_SIZE / (VAL_SIZE + TEST_SIZE)
val_df, test_df = train_test_split(temp_df, test_size=1 - val_ratio_in_temp, random_state=SEED, shuffle=True)

feature_class_counts = [int(feature_infos[c]["num_labels"]) for c in target_cols]

feature_schema = {
    "image_column": image_col,
    "target_count": int(len(target_cols)),
    "targets": target_cols,
    "feature_class_counts": feature_class_counts,
    "excluded_single_label_count": int(len(excluded_single_label)),
    "excluded_single_label_features": excluded_single_label,
    "features": feature_infos,
}
with (PROGRESS_DIR / "feature_schema.json").open("w", encoding="utf-8") as f:
    json.dump(feature_schema, f, ensure_ascii=False, indent=2)

split_stats = {
    "total": int(len(df)),
    "train": int(len(train_df)),
    "val": int(len(val_df)),
    "test": int(len(test_df)),
    "targets_count": int(len(target_cols)),
    "targets": target_cols,
}
with (PROGRESS_DIR / "split_stats.json").open("w", encoding="utf-8") as f:
    json.dump(split_stats, f, ensure_ascii=False, indent=2)
split_stats
# Out:
# Для person-crop обучения выбрано признаков из списка: 115 (кандидатов до фильтрации: 146)
# Признак ''Кусочные', степень выраженности': тип=multiclass, классов=4, есть_пропуски=да, пропусков=5974
# Признак ''Промахивающиеся', степень выраженности': тип=multiclass, классов=4, есть_пропуски=да, пропусков=5295
# Признак 'Аккуратность рисунка': тип=multiclass, классов=3, есть_пропуски=нет, пропусков=0
# Признак 'Аккуратность штриховки (низкая)': тип=binary, классов=2, есть_пропуски=да, пропусков=6468
# Признак 'Аккуратность штриховки (средняя (стандарт))': тип=binary, классов=2, есть_пропуски=да, пропусков=6089
# Признак 'Волосы или шапка (аккуратность)': тип=multiclass, классов=3, есть_пропуски=да, пропусков=4619
# Признак 'Волосы или шапка (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=3898
# Признак 'Голова (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=2188
# Признак 'Голова (искажена форма)': тип=binary, классов=2, есть_пропуски=да, пропусков=6973
# Признак 'Голова (размер)': тип=multiclass, классов=3, есть_пропуски=да, пропусков=5476
# Признак 'Грубые нарушения рисунка (нарушение пропорций)': тип=binary, классов=2, есть_пропуски=да, пропусков=6293
# Признак 'Грубые нарушения рисунка (отклонение от вертикали)': тип=binary, классов=2, есть_пропуски=да, пропусков=6951
# Признак 'Грубые нарушения рисунка (отсутствуют)': тип=binary, классов=2, есть_пропуски=да, пропусков=1495
# Признак 'Два глаза одинаковые': тип=multiclass, классов=3, есть_пропуски=да, пропусков=420
# Признак 'Детали (лицо) (волосы (шапка))': тип=binary, классов=2, есть_пропуски=да, пропусков=1005
# Признак 'Детали (лицо) (глаза (один или оба))': тип=binary, классов=2, есть_пропуски=да, пропусков=421
# Признак 'Детали (лицо) (другое)': тип=binary, классов=2, есть_пропуски=да, пропусков=6986
# Признак 'Детали (лицо) (лоб)': тип=binary, классов=2, есть_пропуски=да, пропусков=1638
# Признак 'Детали (лицо) (нос)': тип=binary, классов=2, есть_пропуски=да, пропусков=2427
# Признак 'Детали (лицо) (рот)': тип=binary, классов=2, есть_пропуски=да, пропусков=604
# Признак 'Детали (лицо) (уши)': тип=binary, классов=2, есть_пропуски=да, пропусков=5399
# Признак 'Детализированность': тип=multiclass, классов=3, есть_пропуски=нет, пропусков=0
# Признак 'Дополнительно (в руке или рядом) (дополнительные предметы отсутствуют)': тип=binary, классов=2, есть_пропуски=да, пропусков=492
# Признак 'Дополнительные детали изображения фигуры (другое)': тип=binary, классов=2, есть_пропуски=да, пропусков=6573
# Признак 'Дополнительные детали изображения фигуры (отсутствуют)': тип=binary, классов=2, есть_пропуски=да, пропусков=3239
# Признак 'Дополнительные детали изображения фигуры (пуговицы)': тип=binary, классов=2, есть_пропуски=да, пропусков=6947
# Признак 'Дополнительные детали изображения фигуры (пуп)': тип=binary, классов=2, есть_пропуски=да, пропусков=7134
# Признак 'Дополнительные детали изображения фигуры (ремень / пояс)': тип=binary, классов=2, есть_пропуски=да, пропусков=6662
# Признак 'Дополнительные детали изображения фигуры (украшения)': тип=binary, классов=2, есть_пропуски=да, пропусков=5642
# Признак 'Дополнительные детали на лице (брови)': тип=binary, классов=2, есть_пропуски=да, пропусков=5133
# Признак 'Дополнительные особенности глаз ('пустые')': тип=binary, классов=2, есть_пропуски=да, пропусков=6712
# Признак 'Дополнительные особенности глаз (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=4262
# Признак 'Дополнительные особенности глаз (закрыты)': тип=binary, классов=2, есть_пропуски=да, пропусков=7149
# Признак 'Дополнительные особенности глаз (зачернена радужка или весь глаз)': тип=binary, классов=2, есть_пропуски=да, пропусков=5153
# Признак 'Дополнительные особенности глаз (подчеркнутый контур)': тип=binary, классов=2, есть_пропуски=да, пропусков=7039
# Признак 'Зубы': тип=multiclass, классов=7, есть_пропуски=да, пропусков=604
# Признак 'Изображение персонажа': тип=binary, классов=2, есть_пропуски=нет, пропусков=0
# Признак 'Кисть (большая)': тип=binary, классов=2, есть_пропуски=да, пропусков=7030
# Признак 'Кисть (маленькая)': тип=binary, классов=2, есть_пропуски=да, пропусков=6928
# Признак 'Кисть (отсутствует)': тип=binary, классов=2, есть_пропуски=да, пропусков=4196
# Признак 'Кисть (средняя (стандарт))': тип=binary, классов=2, есть_пропуски=да, пропусков=4190
# Признак 'Ладонь, пальцы (изображена ладонь)': тип=binary, классов=2, есть_пропуски=да, пропусков=6009
# Признак 'Ладонь, пальцы (изображены пальцы)': тип=binary, классов=2, есть_пропуски=да, пропусков=3338
# Признак 'Ладонь, пальцы (отсутствуют)': тип=binary, классов=2, есть_пропуски=да, пропусков=4896
# Признак 'Ладонь, пальцы (положение 'варежки')': тип=binary, классов=2, есть_пропуски=да, пропусков=6925
# Признак 'Лоб (размер)': тип=multiclass, классов=4, есть_пропуски=да, пропусков=2301
# Признак 'Лоб (скрыт волосами или шапкой)': тип=binary, классов=2, есть_пропуски=да, пропусков=6331
# Признак 'Множественные, степень выраженности': тип=multiclass, классов=4, есть_пропуски=да, пропусков=5458
# Признак 'Нажим (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=1851
# Признак 'Нажим штриховки (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=5818
# Признак 'Ноги (длина)': тип=multiclass, классов=3, есть_пропуски=да, пропусков=6636
# Признак 'Ноги (одна или обе) (положение)': тип=multiclass, классов=3, есть_пропуски=да, пропусков=252
# Признак 'Ноги (постановка)': тип=multiclass, классов=4, есть_пропуски=да, пропусков=635
# Признак 'Нос (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=3098
# Признак 'Нос (увеличен размер)': тип=binary, классов=2, есть_пропуски=да, пропусков=7117
# Признак 'Нос (усилен нажим)': тип=binary, классов=2, есть_пропуски=да, пропусков=7169
# Признак 'Одежда ('рентгеновский' рисунок)': тип=binary, классов=2, есть_пропуски=да, пропусков=7207
# Признак 'Одежда (отсутствует, тело изображено условно)': тип=binary, классов=2, есть_пропуски=да, пропусков=5507
# Признак 'Одежда (реалистичное изображение)': тип=binary, классов=2, есть_пропуски=да, пропусков=5246
# Признак 'Одежда (условное изображение)': тип=binary, классов=2, есть_пропуски=да, пропусков=4259
# Признак 'Особенности линии ('кусочные')': тип=binary, классов=2, есть_пропуски=да, пропусков=5975
# Признак 'Особенности линии ('промахивающиеся')': тип=binary, классов=2, есть_пропуски=да, пропусков=5296
# Признак 'Особенности линии (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=4651
# Признак 'Особенности линии (множественные)': тип=binary, классов=2, есть_пропуски=да, пропусков=5461
# Признак 'Особенности линии (недоведенные)': тип=binary, классов=2, есть_пропуски=да, пропусков=7025
# Признак 'Особенности линии (эскизные)': тип=binary, классов=2, есть_пропуски=да, пропусков=6872
# Признак 'Пальцы (изображены черточками)': тип=binary, классов=2, есть_пропуски=да, пропусков=6679
# Признак 'Пальцы (передана толщина)': тип=binary, классов=2, есть_пропуски=да, пропусков=4124
# Признак 'Поза': тип=multiclass, классов=5, есть_пропуски=нет, пропусков=0
# Признак 'Пол (подчеркнута генитальная область)': тип=binary, классов=2, есть_пропуски=да, пропусков=7210
# Признак 'Пол персонажа': тип=multiclass, классов=4, есть_пропуски=да, пропусков=55
# Признак 'Положение рук (вытянуты в стороны или вперед)': тип=binary, классов=2, есть_пропуски=да, пропусков=6721
# Признак 'Положение рук (дополнительно)': тип=binary, классов=2, есть_пропуски=да, пропусков=6620
# Признак 'Положение рук (за спиной или в карманах)': тип=binary, классов=2, есть_пропуски=да, пропусков=6829
# Признак 'Положение рук (подняты)': тип=binary, классов=2, есть_пропуски=да, пропусков=7023
# Признак 'Положение рук (прижаты к телу (от верха до локтя))': тип=binary, классов=2, есть_пропуски=да, пропусков=6936
# Признак 'Положение рук (свободно опущены)': тип=binary, классов=2, есть_пропуски=да, пропусков=6977
# Признак 'Положение рук (сильно отставлены)': тип=binary, классов=2, есть_пропуски=да, пропусков=6712
# Признак 'Положение рук (слегка отставлены (стандарт))': тип=binary, классов=2, есть_пропуски=да, пропусков=4253
# Признак 'Пуговицы': тип=multiclass, классов=3, есть_пропуски=да, пропусков=6947
# Признак 'Размер глаз': тип=multiclass, классов=4, есть_пропуски=да, пропусков=773
# Признак 'Ракурс': тип=multiclass, классов=4, есть_пропуски=нет, пропусков=0
# Признак 'Расположение на листе (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=5085
# Признак 'Ресницы': тип=multiclass, классов=6, есть_пропуски=да, пропусков=421
# Признак 'Рот': тип=multiclass, классов=7, есть_пропуски=да, пропусков=604
# Признак 'Руки (одна или обе)': тип=multiclass, классов=4, есть_пропуски=нет, пропусков=0
# Признак 'Способ изображения': тип=multiclass, классов=7, есть_пропуски=нет, пропусков=0
# Признак 'Ступни (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=3740
# Признак 'Ступни (зачернены)': тип=binary, классов=2, есть_пропуски=да, пропусков=6851
# Признак 'Ступни (отсутствуют)': тип=binary, классов=2, есть_пропуски=да, пропусков=5527
# Признак 'Ступни (размер)': тип=multiclass, классов=3, есть_пропуски=да, пропусков=6392
# Признак 'Тело (вытянутое)': тип=binary, классов=2, есть_пропуски=да, пропусков=6942
# Признак 'Тело (округлое)': тип=binary, классов=2, есть_пропуски=да, пропусков=6488
# Признак 'Тело (прямоугольное)': тип=binary, классов=2, есть_пропуски=да, пропусков=5149
# Признак 'Тело (реалистичное)': тип=binary, классов=2, есть_пропуски=да, пропусков=4195
# Признак 'Тело (треугольное)': тип=binary, классов=2, есть_пропуски=да, пропусков=6831
# Признак 'Тело (широкое)': тип=binary, классов=2, есть_пропуски=да, пропусков=7135
# Признак 'Украшения, узор на одежде': тип=multiclass, классов=3, есть_пропуски=да, пропусков=5642
# Признак 'Устойчивость изображенного человека': тип=multiclass, классов=4, есть_пропуски=нет, пропусков=0
# Признак 'Уши (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=5916
# Признак 'Уши (преувеличен размер)': тип=binary, классов=2, есть_пропуски=да, пропусков=7118
# Признак 'Фигура в движении': тип=binary, классов=2, есть_пропуски=нет, пропусков=0
# Признак 'Форма глаз ('мультяшные')': тип=binary, классов=2, есть_пропуски=да, пропусков=7180
# Признак 'Форма глаз (круг)': тип=binary, классов=2, есть_пропуски=да, пропусков=4733
# Признак 'Форма глаз (овал, реалистичная форма)': тип=binary, классов=2, есть_пропуски=да, пропусков=4600
# Признак 'Форма глаз (точка)': тип=binary, классов=2, есть_пропуски=да, пропусков=6862
# Признак 'Форма глаз (черточка)': тип=binary, классов=2, есть_пропуски=да, пропусков=7082
# Признак 'Шея (без особенностей)': тип=binary, классов=2, есть_пропуски=да, пропусков=3979
# Признак 'Шея (длинная)': тип=binary, классов=2, есть_пропуски=да, пропусков=6418
# Признак 'Шея (короткая)': тип=binary, классов=2, есть_пропуски=да, пропусков=6969
# Признак 'Шея (отсутствует)': тип=binary, классов=2, есть_пропуски=да, пропусков=5493
# Признак 'Шея (размер)': тип=multiclass, классов=3, есть_пропуски=да, пропусков=6184
# Признак 'Шея отделена от тела линией': тип=multiclass, классов=6, есть_пропуски=нет, пропусков=0
# Признак 'Эскизные, степень выраженности': тип=multiclass, классов=4, есть_пропуски=да, пропусков=6871
# Признак 'Язык': тип=multiclass, классов=3, есть_пропуски=да, пропусков=604
# Признаков всего: 115 | исключено одно-классовых: 0 | итоговых признаков: 115
# {'total': 7392,
#  'train': 5913,
#  'val': 739,
#  'test': 740,
#  'targets_count': 115,
#  'targets': ["'Кусочные', степень выраженности",
#   "'Промахивающиеся', степень выраженности",
#   'Аккуратность рисунка',
#   'Аккуратность штриховки (низкая)',
#   'Аккуратность штриховки (средняя (стандарт))',
#   'Волосы или шапка (аккуратность)',
#   'Волосы или шапка (без особенностей)',
#   'Голова (без особенностей)',
#   'Голова (искажена форма)',
#   'Голова (размер)',
#   'Грубые нарушения рисунка (нарушение пропорций)',
#   'Грубые нарушения рисунка (отклонение от вертикали)',
#   'Грубые нарушения рисунка (отсутствуют)',
#   'Два глаза одинаковые',
#   'Детали (лицо) (волосы (шапка))',
#   'Детали (лицо) (глаза (один или оба))',
#   'Детали (лицо) (другое)',
#   'Детали (лицо) (лоб)',
#   'Детали (лицо) (нос)',
#   'Детали (лицо) (рот)',
#   'Детали (лицо) (уши)',
#   'Детализированность',
#   'Дополнительно (в руке или рядом) (дополнительные предметы отсутствуют)',
#   'Дополнительные детали изображения фигуры (другое)',
#   'Дополнительные детали изображения фигуры (отсутствуют)',
#   'Дополнительные детали изображения фигуры (пуговицы)',
#   'Дополнительные детали изображения фигуры (пуп)',
#   'Дополнительные детали изображения фигуры (ремень / пояс)',
#   'Дополнительные детали изображения фигуры (украшения)',
#   'Дополнительные детали на лице (брови)',
#   "Дополнительные особенности глаз ('пустые')",
#   'Дополнительные особенности глаз (без особенностей)',
#   'Дополнительные особенности глаз (закрыты)',
#   'Дополнительные особенности глаз (зачернена радужка или весь глаз)',
#   'Дополнительные особенности глаз (подчеркнутый контур)',
#   'Зубы',
#   'Изображение персонажа',
#   'Кисть (большая)',
#   'Кисть (маленькая)',
#   'Кисть (отсутствует)',
#   'Кисть (средняя (стандарт))',
#   'Ладонь, пальцы (изображена ладонь)',
#   'Ладонь, пальцы (изображены пальцы)',
#   'Ладонь, пальцы (отсутствуют)',
#   "Ладонь, пальцы (положение 'варежки')",
#   'Лоб (размер)',
#   'Лоб (скрыт волосами или шапкой)',
#   'Множественные, степень выраженности',
#   'Нажим (без особенностей)',
#   'Нажим штриховки (без особенностей)',
#   'Ноги (длина)',
#   'Ноги (одна или обе) (положение)',
#   'Ноги (постановка)',
#   'Нос (без особенностей)',
#   'Нос (увеличен размер)',
#   'Нос (усилен нажим)',
#   "Одежда ('рентгеновский' рисунок)",
#   'Одежда (отсутствует, тело изображено условно)',
#   'Одежда (реалистичное изображение)',
#   'Одежда (условное изображение)',
#   "Особенности линии ('кусочные')",
#   "Особенности линии ('промахивающиеся')",
#   'Особенности линии (без особенностей)',
#   'Особенности линии (множественные)',
#   'Особенности линии (недоведенные)',
#   'Особенности линии (эскизные)',
#   'Пальцы (изображены черточками)',
#   'Пальцы (передана толщина)',
#   'Поза',
#   'Пол (подчеркнута генитальная область)',
#   'Пол персонажа',
#   'Положение рук (вытянуты в стороны или вперед)',
#   'Положение рук (дополнительно)',
#   'Положение рук (за спиной или в карманах)',
#   'Положение рук (подняты)',
#   'Положение рук (прижаты к телу (от верха до локтя))',
#   'Положение рук (свободно опущены)',
#   'Положение рук (сильно отставлены)',
#   'Положение рук (слегка отставлены (стандарт))',
#   'Пуговицы',
#   'Размер глаз',
#   'Ракурс',
#   'Расположение на листе (без особенностей)',
#   'Ресницы',
#   'Рот',
#   'Руки (одна или обе)',
#   'Способ изображения',
#   'Ступни (без особенностей)',
#   'Ступни (зачернены)',
#   'Ступни (отсутствуют)',
#   'Ступни (размер)',
#   'Тело (вытянутое)',
#   'Тело (округлое)',
#   'Тело (прямоугольное)',
#   'Тело (реалистичное)',
#   'Тело (треугольное)',
#   'Тело (широкое)',
#   'Украшения, узор на одежде',
#   'Устойчивость изображенного человека',
#   'Уши (без особенностей)',
#   'Уши (преувеличен размер)',
#   'Фигура в движении',
#   "Форма глаз ('мультяшные')",
#   'Форма глаз (круг)',
#   'Форма глаз (овал, реалистичная форма)',
#   'Форма глаз (точка)',
#   'Форма глаз (черточка)',
#   'Шея (без особенностей)',
#   'Шея (длинная)',
#   'Шея (короткая)',
#   'Шея (отсутствует)',
#   'Шея (размер)',
#   'Шея отделена от тела линией',
#   'Эскизные, степень выраженности',
#   'Язык']}

# %% [markdown]
# ## C. Build split records with YOLO person crops

# %%
def valid_crop(path: Path) -> bool:
    return path.exists() and path.stat().st_size > 0


def resolve_existing_person_crop(person_dir: Path, src_stem: str, idx: int):
    exact = person_dir / f"{src_stem}_{idx}.png"
    if valid_crop(exact):
        return exact
    plain = person_dir / f"{src_stem}.png"
    if valid_crop(plain):
        return plain
    matches = sorted(person_dir.glob(f"{src_stem}_*.png"))
    for m in matches:
        if valid_crop(m):
            return m
    return None


def split_crop_status(split_name: str, split_df: pd.DataFrame):
    person_dir = PERSON_CROPS_DIR / split_name
    person_dir.mkdir(parents=True, exist_ok=True)
    total = int(len(split_df))
    missing_person = 0
    for i, row in split_df.reset_index(drop=True).iterrows():
        src = Path(row["resolved_image"])
        existing = resolve_existing_person_crop(person_dir, src.stem, i)
        if existing is None:
            missing_person += 1
    return {
        "split": split_name,
        "total": total,
        "missing_person": missing_person,
    }


status_before = {
    "train": split_crop_status("train", train_df),
    "val": split_crop_status("val", val_df),
    "test": split_crop_status("test", test_df),
}
print(f"Режим этапа кропов: {CROP_STAGE_MODE}")
print(f"Состояние train: {status_before['train']}")
print(f"Состояние val: {status_before['val']}")
print(f"Состояние test: {status_before['test']}")

need_yolo = any(v["missing_person"] > 0 for v in status_before.values())


def should_use_yolo(need_yolo: bool, stage_mode: str, allow_autofill: bool) -> bool:
    if stage_mode == "always":
        return True
    if stage_mode == "never":
        return False
    return bool(need_yolo and allow_autofill)


use_yolo = should_use_yolo(need_yolo, CROP_STAGE_MODE, ALLOW_YOLO_AUTOFILL)

if need_yolo and not use_yolo:
    print("Этап YOLO отключен: есть недостающие кропы, но автодозаполнение выключено")
else:
    stage_text = "включен" if use_yolo else "пропущен"
    print(f"Этап YOLO: {stage_text}; требуется YOLO: {'да' if need_yolo else 'нет'}")

if use_yolo:
    yolo_model = YOLO(str(YOLO_WEIGHTS))
    names = yolo_model.names if hasattr(yolo_model, "names") else {}
else:
    yolo_model = None
    names = {}


def get_class_id(target_name: str, fallback: int) -> int:
    if isinstance(names, dict):
        for k, v in names.items():
            if str(v).strip().lower() == target_name:
                return int(k)
    return fallback


person_class_id = get_class_id("персонаж", 2)


def crop_best_class(src_path: Path, dst_path: Path, class_id: int):
    idx = int(dst_path.stem.rsplit("_", 1)[-1]) if "_" in dst_path.stem and dst_path.stem.rsplit("_", 1)[-1].isdigit() else -1
    existing = resolve_existing_person_crop(dst_path.parent, src_path.stem, idx)
    if existing is not None:
        return "reused", existing
    if yolo_model is None:
        return "missing", None
    results = yolo_model.predict(source=str(src_path), conf=YOLO_CONF, imgsz=YOLO_IMGSZ, classes=[class_id], device=DEVICE, verbose=False)
    if not results:
        return "missing", None
    boxes = results[0].boxes
    if boxes is None or len(boxes) == 0:
        return "missing", None
    conf = boxes.conf.detach().cpu().numpy()
    best_idx = int(np.argmax(conf))
    xyxy = boxes.xyxy[best_idx].detach().cpu().numpy().tolist()
    x1, y1, x2, y2 = [int(v) for v in xyxy]
    with Image.open(src_path).convert("RGB") as img:
        w, h = img.size
        x1 = max(0, min(x1, w - 1))
        y1 = max(0, min(y1, h - 1))
        x2 = max(x1 + 1, min(x2, w))
        y2 = max(y1 + 1, min(y2, h))
        crop = img.crop((x1, y1, x2, y2))
        crop.save(dst_path)
    return "created", dst_path


def build_split_records(split_name: str, split_df: pd.DataFrame):
    person_dir = PERSON_CROPS_DIR / split_name
    person_dir.mkdir(parents=True, exist_ok=True)
    records = []
    dropped_person = 0
    reused_person = 0
    created_person = 0
    total_items = int(len(split_df))
    for i, row in split_df.reset_index(drop=True).iterrows():
        src = Path(row["resolved_image"])
        person_dst = person_dir / f"{src.stem}_{i}.png"
        person_status, person_path = crop_best_class(src, person_dst, person_class_id)
        if person_status == "reused":
            reused_person += 1
        if person_status == "created":
            created_person += 1
        if person_status == "missing":
            dropped_person += 1
        else:
            records.append({"image": str(person_path), "target": [int(v) for v in row["encoded_targets"]]})
        processed = i + 1
        if processed % 100 == 0 or processed == total_items:
            print(
                f"Сплит '{split_name}': обработано {processed}/{total_items}, "
                f"сохранено={len(records)}, переиспользовано={reused_person}, "
                f"создано={created_person}, пропущено={dropped_person}"
            )
    report = {
        "split": split_name,
        "kept_person_for_training": len(records),
        "dropped_person": dropped_person,
        "reused_person": reused_person,
        "created_person": created_person,
        "reuse_existing_crops": REUSE_EXISTING_CROPS,
        "crop_stage_mode": CROP_STAGE_MODE,
        "used_yolo": bool(use_yolo),
    }
    with (PROGRESS_DIR / f"crop_report_{split_name}.json").open("w", encoding="utf-8") as f:
        json.dump(report, f, ensure_ascii=False, indent=2)
    with (OUTPUT_DIR / f"{split_name}_records.json").open("w", encoding="utf-8") as f:
        json.dump(records, f, ensure_ascii=False)
    return records, report


train_records, train_report = build_split_records("train", train_df)
val_records, val_report = build_split_records("val", val_df)
test_records, test_report = build_split_records("test", test_df)

{"train": train_report, "val": val_report, "test": test_report, "used_yolo": bool(use_yolo)}
# Out:
# Режим этапа кропов: auto
# Состояние train: {'split': 'train', 'total': 5913, 'missing_person': 1}
# Состояние val: {'split': 'val', 'total': 739, 'missing_person': 0}
# Состояние test: {'split': 'test', 'total': 740, 'missing_person': 0}
# Этап YOLO: включен; требуется YOLO: да
# Сплит 'train': обработано 100/5913, сохранено=100, переиспользовано=100, создано=0, пропущено=0
# Сплит 'train': обработано 200/5913, сохранено=200, переиспользовано=200, создано=0, пропущено=0
# Сплит 'train': обработано 300/5913, сохранено=300, переиспользовано=300, создано=0, пропущено=0
# Сплит 'train': обработано 400/5913, сохранено=400, переиспользовано=400, создано=0, пропущено=0
# Сплит 'train': обработано 500/5913, сохранено=500, переиспользовано=500, создано=0, пропущено=0
# Сплит 'train': обработано 600/5913, сохранено=600, переиспользовано=600, создано=0, пропущено=0
# Сплит 'train': обработано 700/5913, сохранено=700, переиспользовано=700, создано=0, пропущено=0
# Сплит 'train': обработано 800/5913, сохранено=800, переиспользовано=800, создано=0, пропущено=0
# Сплит 'train': обработано 900/5913, сохранено=900, переиспользовано=900, создано=0, пропущено=0
# Сплит 'train': обработано 1000/5913, сохранено=999, переиспользовано=999, создано=0, пропущено=1
# Сплит 'train': обработано 1100/5913, сохранено=1099, переиспользовано=1099, создано=0, пропущено=1
# Сплит 'train': обработано 1200/5913, сохранено=1199, переиспользовано=1199, создано=0, пропущено=1
# Сплит 'train': обработано 1300/5913, сохранено=1299, переиспользовано=1299, создано=0, пропущено=1
# Сплит 'train': обработано 1400/5913, сохранено=1399, переиспользовано=1399, создано=0, пропущено=1
# Сплит 'train': обработано 1500/5913, сохранено=1499, переиспользовано=1499, создано=0, пропущено=1
# Сплит 'train': обработано 1600/5913, сохранено=1599, переиспользовано=1599, создано=0, пропущено=1
# Сплит 'train': обработано 1700/5913, сохранено=1699, переиспользовано=1699, создано=0, пропущено=1
# Сплит 'train': обработано 1800/5913, сохранено=1799, переиспользовано=1799, создано=0, пропущено=1
# Сплит 'train': обработано 1900/5913, сохранено=1899, переиспользовано=1899, создано=0, пропущено=1
# Сплит 'train': обработано 2000/5913, сохранено=1999, переиспользовано=1999, создано=0, пропущено=1
# Сплит 'train': обработано 2100/5913, сохранено=2099, переиспользовано=2099, создано=0, пропущено=1
# Сплит 'train': обработано 2200/5913, сохранено=2199, переиспользовано=2199, создано=0, пропущено=1
# Сплит 'train': обработано 2300/5913, сохранено=2299, переиспользовано=2299, создано=0, пропущено=1
# Сплит 'train': обработано 2400/5913, сохранено=2399, переиспользовано=2399, создано=0, пропущено=1
# Сплит 'train': обработано 2500/5913, сохранено=2499, переиспользовано=2499, создано=0, пропущено=1
# Сплит 'train': обработано 2600/5913, сохранено=2599, переиспользовано=2599, создано=0, пропущено=1
# Сплит 'train': обработано 2700/5913, сохранено=2699, переиспользовано=2699, создано=0, пропущено=1
# Сплит 'train': обработано 2800/5913, сохранено=2799, переиспользовано=2799, создано=0, пропущено=1
# Сплит 'train': обработано 2900/5913, сохранено=2899, переиспользовано=2899, создано=0, пропущено=1
# Сплит 'train': обработано 3000/5913, сохранено=2999, переиспользовано=2999, создано=0, пропущено=1
# Сплит 'train': обработано 3100/5913, сохранено=3099, переиспользовано=3099, создано=0, пропущено=1
# Сплит 'train': обработано 3200/5913, сохранено=3199, переиспользовано=3199, создано=0, пропущено=1
# Сплит 'train': обработано 3300/5913, сохранено=3299, переиспользовано=3299, создано=0, пропущено=1
# Сплит 'train': обработано 3400/5913, сохранено=3399, переиспользовано=3399, создано=0, пропущено=1
# Сплит 'train': обработано 3500/5913, сохранено=3499, переиспользовано=3499, создано=0, пропущено=1
# Сплит 'train': обработано 3600/5913, сохранено=3599, переиспользовано=3599, создано=0, пропущено=1
# Сплит 'train': обработано 3700/5913, сохранено=3699, переиспользовано=3699, создано=0, пропущено=1
# Сплит 'train': обработано 3800/5913, сохранено=3799, переиспользовано=3799, создано=0, пропущено=1
# Сплит 'train': обработано 3900/5913, сохранено=3899, переиспользовано=3899, создано=0, пропущено=1
# Сплит 'train': обработано 4000/5913, сохранено=3999, переиспользовано=3999, создано=0, пропущено=1
# Сплит 'train': обработано 4100/5913, сохранено=4099, переиспользовано=4099, создано=0, пропущено=1
# Сплит 'train': обработано 4200/5913, сохранено=4199, переиспользовано=4199, создано=0, пропущено=1
# Сплит 'train': обработано 4300/5913, сохранено=4299, переиспользовано=4299, создано=0, пропущено=1
# Сплит 'train': обработано 4400/5913, сохранено=4399, переиспользовано=4399, создано=0, пропущено=1
# Сплит 'train': обработано 4500/5913, сохранено=4499, переиспользовано=4499, создано=0, пропущено=1
# Сплит 'train': обработано 4600/5913, сохранено=4599, переиспользовано=4599, создано=0, пропущено=1
# Сплит 'train': обработано 4700/5913, сохранено=4699, переиспользовано=4699, создано=0, пропущено=1
# Сплит 'train': обработано 4800/5913, сохранено=4799, переиспользовано=4799, создано=0, пропущено=1
# Сплит 'train': обработано 4900/5913, сохранено=4899, переиспользовано=4899, создано=0, пропущено=1
# Сплит 'train': обработано 5000/5913, сохранено=4999, переиспользовано=4999, создано=0, пропущено=1
# Сплит 'train': обработано 5100/5913, сохранено=5099, переиспользовано=5099, создано=0, пропущено=1
# Сплит 'train': обработано 5200/5913, сохранено=5199, переиспользовано=5199, создано=0, пропущено=1
# Сплит 'train': обработано 5300/5913, сохранено=5299, переиспользовано=5299, создано=0, пропущено=1
# Сплит 'train': обработано 5400/5913, сохранено=5399, переиспользовано=5399, создано=0, пропущено=1
# Сплит 'train': обработано 5500/5913, сохранено=5499, переиспользовано=5499, создано=0, пропущено=1
# Сплит 'train': обработано 5600/5913, сохранено=5599, переиспользовано=5599, создано=0, пропущено=1
# Сплит 'train': обработано 5700/5913, сохранено=5699, переиспользовано=5699, создано=0, пропущено=1
# Сплит 'train': обработано 5800/5913, сохранено=5799, переиспользовано=5799, создано=0, пропущено=1
# Сплит 'train': обработано 5900/5913, сохранено=5899, переиспользовано=5899, создано=0, пропущено=1
# Сплит 'train': обработано 5913/5913, сохранено=5912, переиспользовано=5912, создано=0, пропущено=1
# Сплит 'val': обработано 100/739, сохранено=100, переиспользовано=100, создано=0, пропущено=0
# Сплит 'val': обработано 200/739, сохранено=200, переиспользовано=200, создано=0, пропущено=0
# Сплит 'val': обработано 300/739, сохранено=300, переиспользовано=300, создано=0, пропущено=0
# Сплит 'val': обработано 400/739, сохранено=400, переиспользовано=400, создано=0, пропущено=0
# Сплит 'val': обработано 500/739, сохранено=500, переиспользовано=500, создано=0, пропущено=0
# Сплит 'val': обработано 600/739, сохранено=600, переиспользовано=600, создано=0, пропущено=0
# Сплит 'val': обработано 700/739, сохранено=700, переиспользовано=700, создано=0, пропущено=0
# Сплит 'val': обработано 739/739, сохранено=739, переиспользовано=739, создано=0, пропущено=0
# Сплит 'test': обработано 100/740, сохранено=100, переиспользовано=100, создано=0, пропущено=0
# Сплит 'test': обработано 200/740, сохранено=200, переиспользовано=200, создано=0, пропущено=0
# Сплит 'test': обработано 300/740, сохранено=300, переиспользовано=300, создано=0, пропущено=0
# Сплит 'test': обработано 400/740, сохранено=400, переиспользовано=400, создано=0, пропущено=0
# Сплит 'test': обработано 500/740, сохранено=500, переиспользовано=500, создано=0, пропущено=0
# Сплит 'test': обработано 600/740, сохранено=600, переиспользовано=600, создано=0, пропущено=0
# Сплит 'test': обработано 700/740, сохранено=700, переиспользовано=700, создано=0, пропущено=0
# Сплит 'test': обработано 740/740, сохранено=740, переиспользовано=740, создано=0, пропущено=0
# {'train': {'split': 'train',
#   'kept_person_for_training': 5912,
#   'dropped_person': 1,
#   'reused_person': 5912,
#   'created_person': 0,
#   'reuse_existing_crops': False,
#   'crop_stage_mode': 'auto',
#   'used_yolo': True},
#  'val': {'split': 'val',
#   'kept_person_for_training': 739,
#   'dropped_person': 0,
#   'reused_person': 739,
#   'created_person': 0,
#   'reuse_existing_crops': False,
#   'crop_stage_mode': 'auto',
#   'used_yolo': True},
#  'test': {'split': 'test',
#   'kept_person_for_training': 740,
#   'dropped_person': 0,
#   'reused_person': 740,
#   'created_person': 0,
#   'reuse_existing_crops': False,
#   'crop_stage_mode': 'auto',
#   'used_yolo': True},
#  'used_yolo': True}

# %% [markdown]
# ## D. Dataset and model initialization

# %%
class MultiTaskImageDataset(Dataset):
    def __init__(self, records, transform, split_name):
        self.records = [r for r in records if Path(r["image"]).exists()]
        self.transform = transform
        dropped = int(len(records) - len(self.records))
        if dropped > 0:
            print(f"Сплит '{split_name}': пропущено отсутствующих файлов={dropped}, оставлено={len(self.records)}")

    def __len__(self):
        return len(self.records)

    def __getitem__(self, idx):
        rec = self.records[idx]
        img = Image.open(rec["image"]).convert("RGB")
        x = self.transform(img)
        y = torch.tensor(rec["target"], dtype=torch.long)
        return x, y


class ResNetMultiHead(nn.Module):
    def __init__(self, class_counts, backbone_name):
        super().__init__()
        if backbone_name == "resnet152":
            backbone = models.resnet152(weights=models.ResNet152_Weights.DEFAULT)
        elif backbone_name == "resnet101":
            backbone = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
        in_features = backbone.fc.in_features
        backbone.fc = nn.Identity()
        self.backbone = backbone
        self.heads = nn.ModuleList([nn.Linear(in_features, int(c)) for c in class_counts])

    def forward(self, x):
        feat = self.backbone(x)
        return [head(feat) for head in self.heads]


train_tf = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
eval_tf = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

train_ds = MultiTaskImageDataset(train_records, train_tf, "train")
val_ds = MultiTaskImageDataset(val_records, eval_tf, "val")
test_ds = MultiTaskImageDataset(test_records, eval_tf, "test")

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

model = ResNetMultiHead(feature_class_counts, BACKBONE).to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)

# %% [markdown]
# ## E. Model training loop

# %%
def epoch_pass(loader, model, optimizer=None, epoch=0, mode="train"):
    train_mode = optimizer is not None
    model.train(train_mode)
    total_loss = 0.0
    total_count = 0
    acc_sum = 0.0
    pbar = tqdm(loader, desc=f"{mode} {epoch}/{EPOCHS}", leave=False)
    for x, y in pbar:
        x = x.to(DEVICE)
        y = y.to(DEVICE)
        logits_list = model(x)
        losses = []
        pred_list = []
        for i, logits in enumerate(logits_list):
            yi = y[:, i]
            losses.append(nn.functional.cross_entropy(logits, yi))
            pred_list.append(logits.argmax(dim=1))
        loss = torch.stack(losses).mean()
        if train_mode:
            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            optimizer.step()
        with torch.no_grad():
            per_feature_acc = torch.stack([(pred_list[i] == y[:, i]).float().mean() for i in range(len(pred_list))])
            batch_acc = per_feature_acc.mean().item()
        pbar.set_postfix({"loss": f"{loss.item():.4f}", "acc": f"{batch_acc:.4f}"})
        bsz = x.size(0)
        total_loss += loss.item() * bsz
        acc_sum += batch_acc * bsz
        total_count += bsz
    return total_loss / total_count, acc_sum / total_count


def evaluate_f1(loader, model, per_feature=False):
    model.eval()
    all_true = []
    all_pred = []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(DEVICE)
            logits_list = model(x)
            preds = torch.stack([logits.argmax(dim=1) for logits in logits_list], dim=1).cpu().numpy().astype(np.int32)
            all_pred.append(preds)
            all_true.append(y.numpy().astype(np.int32))
    y_true = np.vstack(all_true)
    y_pred = np.vstack(all_pred)
    flat_true = y_true.reshape(-1)
    flat_pred = y_pred.reshape(-1)
    out = {
        "f1_micro": float(f1_score(flat_true, flat_pred, average="micro", zero_division=0)),
        "f1_macro": float(f1_score(flat_true, flat_pred, average="macro", zero_division=0)),
        "f1_weighted": float(f1_score(flat_true, flat_pred, average="weighted", zero_division=0)),
    }
    if per_feature:
        out["f1_per_feature_macro"] = {
            k: float(f1_score(y_true[:, i], y_pred[:, i], average="macro", zero_division=0))
            for i, k in enumerate(target_cols)
        }
    return out


history = []
for epoch in tqdm(range(1, EPOCHS + 1), desc="epochs"):
    t0 = time.time()
    train_loss, train_acc = epoch_pass(train_loader, model, optimizer, epoch=epoch, mode="train")
    val_loss, val_acc = epoch_pass(val_loader, model, optimizer=None, epoch=epoch, mode="val")
    val_f1 = evaluate_f1(val_loader, model, per_feature=VAL_COMPUTE_PER_FEATURE_F1)
    rec = {
        "epoch": epoch,
        "train_loss": float(train_loss),
        "train_accuracy": float(train_acc),
        "val_loss": float(val_loss),
        "val_accuracy": float(val_acc),
        "val_f1_micro": float(val_f1["f1_micro"]),
        "val_f1_macro": float(val_f1["f1_macro"]),
        "val_f1_weighted": float(val_f1["f1_weighted"]),
        "seconds": float(time.time() - t0),
    }
    if VAL_COMPUTE_PER_FEATURE_F1:
        rec["val_f1_per_feature_macro"] = val_f1["f1_per_feature_macro"]
    history.append(rec)
    print(
        f"Эпоха {epoch}: train_loss={rec['train_loss']:.4f}, val_loss={rec['val_loss']:.4f}, "
        f"train_acc={rec['train_accuracy']:.4f}, val_acc={rec['val_accuracy']:.4f}, "
        f"val_f1_macro={rec['val_f1_macro']:.4f}, время={rec['seconds']:.1f}с"
    )
    with (PROGRESS_DIR / "epochs" / f"epoch_{epoch:03d}.json").open("w", encoding="utf-8") as f:
        json.dump(rec, f, ensure_ascii=False, indent=2)
    with (PROGRESS_DIR / "history.json").open("w", encoding="utf-8") as f:
        json.dump(history, f, ensure_ascii=False, indent=2)

torch.save({
    "backbone": BACKBONE,
    "model_state_dict": model.state_dict(),
    "target_cols": target_cols,
    "feature_class_counts": feature_class_counts,
    "feature_infos": feature_infos,
}, OUTPUT_DIR / "resnet152_person_multitask.pth")
history_df = pd.DataFrame(history)
history_df
# Out:
# epochs:   0%|          | 0/5 [00:00<?, ?it/s]
# train 1/5:   0%|          | 0/370 [00:00<?, ?it/s]
# val 1/5:   0%|          | 0/47 [00:00<?, ?it/s]
# Эпоха 1: train_loss=0.4522, val_loss=0.3942, train_acc=0.8163, val_acc=0.8414, val_f1_macro=0.7131, время=635.7с
# train 2/5:   0%|          | 0/370 [00:00<?, ?it/s]
# val 2/5:   0%|          | 0/47 [00:00<?, ?it/s]
# Эпоха 2: train_loss=0.3780, val_loss=0.3647, train_acc=0.8474, val_acc=0.8537, val_f1_macro=0.7433, время=638.4с
# train 3/5:   0%|          | 0/370 [00:00<?, ?it/s]
# val 3/5:   0%|          | 0/47 [00:00<?, ?it/s]
# Эпоха 3: train_loss=0.3437, val_loss=0.3521, train_acc=0.8609, val_acc=0.8586, val_f1_macro=0.7494, время=643.0с
# train 4/5:   0%|          | 0/370 [00:00<?, ?it/s]
# val 4/5:   0%|          | 0/47 [00:00<?, ?it/s]
# Эпоха 4: train_loss=0.3157, val_loss=0.3514, train_acc=0.8722, val_acc=0.8592, val_f1_macro=0.7556, время=624.8с
# train 5/5:   0%|          | 0/370 [00:00<?, ?it/s]
# val 5/5:   0%|          | 0/47 [00:00<?, ?it/s]
# Эпоха 5: train_loss=0.2884, val_loss=0.3478, train_acc=0.8834, val_acc=0.8602, val_f1_macro=0.7645, время=620.1с
#    epoch  train_loss  train_accuracy  val_loss  val_accuracy  val_f1_micro  \
# 0      1    0.452225        0.816298  0.394183      0.841431      0.841431
# 1      2    0.377958        0.847411  0.364690      0.853727      0.853727
# 2      3    0.343737        0.860887  0.352077      0.858634      0.858634
# 3      4    0.315709        0.872244  0.351408      0.859175      0.859175
# 4      5    0.288378        0.883426  0.347831      0.860152      0.860152
#
#    val_f1_macro  val_f1_weighted     seconds
# 0      0.713131         0.836241  635.729372
# 1      0.743284         0.850121  638.387961
# 2      0.749394         0.855767  643.032947
# 3      0.755577         0.856411  624.786945
# 4      0.764525         0.857469  620.100915

# %% [markdown]
# ## F. Training curves

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 4))
axes[0].plot(history_df["epoch"], history_df["train_loss"], label="train_loss")
axes[0].plot(history_df["epoch"], history_df["val_loss"], label="val_loss")
axes[0].set_xlabel("epoch")
axes[0].set_ylabel("loss")
axes[0].legend()

axes[1].plot(history_df["epoch"], history_df["train_accuracy"], label="train_accuracy")
axes[1].plot(history_df["epoch"], history_df["val_accuracy"], label="val_accuracy")
axes[1].set_xlabel("epoch")
axes[1].set_ylabel("accuracy")
axes[1].legend()

f1_metrics = ["val_f1_micro", "val_f1_macro", "val_f1_weighted"]
for metric_name in f1_metrics:
    if metric_name in history_df.columns:
        axes[2].plot(history_df["epoch"], history_df[metric_name], label=metric_name)
axes[2].set_xlabel("epoch")
axes[2].set_ylabel("f1")
axes[2].legend()

plot_path = OUTPUT_DIR / "training_curves.png"
fig.tight_layout()
fig.savefig(plot_path, dpi=150)
str(plot_path.resolve())
# Out:
# 'E:\\SosedTemporary\\WorkingSpace\\Narabotki\\26-05-18_1\\resnet152_person_output\\training_curves.png'

# %% [markdown]
# ## G. Standalone test F1 evaluation

# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
from PIL import Image

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from sklearn.metrics import f1_score

ROOT = Path.cwd()
OUTPUT_DIR = ROOT / "resnet152_person_output"
CKPT_PATH = OUTPUT_DIR / "resnet152_person_multitask.pth"
TEST_RECORDS_PATH = OUTPUT_DIR / "test_records.json"
BATCH_SIZE = 16
IMG_SIZE = 224
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

ckpt = torch.load(CKPT_PATH, map_location="cpu")
target_cols = ckpt["target_cols"]
feature_class_counts = ckpt["feature_class_counts"]

class ResNetMultiHead(nn.Module):
    def __init__(self, class_counts):
        super().__init__()
        backbone = models.resnet152(weights=None)
        in_features = backbone.fc.in_features
        backbone.fc = nn.Identity()
        self.backbone = backbone
        self.heads = nn.ModuleList([nn.Linear(in_features, int(c)) for c in class_counts])

    def forward(self, x):
        feat = self.backbone(x)
        return [head(feat) for head in self.heads]

model = ResNetMultiHead(feature_class_counts)
model.load_state_dict(ckpt["model_state_dict"])
model = model.to(DEVICE)
model.eval()

eval_tf = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

records = json.loads(TEST_RECORDS_PATH.read_text(encoding="utf-8"))
records = [r for r in records if Path(r["image"]).exists()]

class MultiTaskImageDataset(Dataset):
    def __init__(self, records, transform):
        self.records = records
        self.transform = transform

    def __len__(self):
        return len(self.records)

    def __getitem__(self, idx):
        rec = self.records[idx]
        img = Image.open(rec["image"]).convert("RGB")
        x = self.transform(img)
        y = torch.tensor(rec["target"], dtype=torch.long)
        return x, y

test_ds = MultiTaskImageDataset(records, eval_tf)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

all_true = []
all_pred = []
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(DEVICE)
        logits_list = model(x)
        preds = torch.stack([logits.argmax(dim=1) for logits in logits_list], dim=1).cpu().numpy().astype(np.int32)
        all_pred.append(preds)
        all_true.append(y.numpy().astype(np.int32))

y_true = np.vstack(all_true)
y_pred = np.vstack(all_pred)

flat_true = y_true.reshape(-1)
flat_pred = y_pred.reshape(-1)
f1_micro = f1_score(flat_true, flat_pred, average="micro", zero_division=0)
f1_macro = f1_score(flat_true, flat_pred, average="macro", zero_division=0)
f1_weighted = f1_score(flat_true, flat_pred, average="weighted", zero_division=0)

f1_per_feature_micro = [f1_score(y_true[:, i], y_pred[:, i], average="micro", zero_division=0) for i in range(y_true.shape[1])]
f1_per_feature_macro = [f1_score(y_true[:, i], y_pred[:, i], average="macro", zero_division=0) for i in range(y_true.shape[1])]
f1_per_feature_weighted = [f1_score(y_true[:, i], y_pred[:, i], average="weighted", zero_division=0) for i in range(y_true.shape[1])]

summary_df = pd.DataFrame([
    {"metric": "f1_micro", "value": float(f1_micro)},
    {"metric": "f1_macro", "value": float(f1_macro)},
    {"metric": "f1_weighted", "value": float(f1_weighted)},
])
per_feature_df = pd.DataFrame({
    "feature": target_cols,
    "num_labels": feature_class_counts,
    "f1_micro": f1_per_feature_micro,
    "f1_macro": f1_per_feature_macro,
    "f1_weighted": f1_per_feature_weighted,
})

xlsx_path = OUTPUT_DIR / "test_f1_metrics.xlsx"
with pd.ExcelWriter(xlsx_path) as writer:
    summary_df.to_excel(writer, index=False, sheet_name="summary")
    per_feature_df.to_excel(writer, index=False, sheet_name="per_feature")

f1_json = {
    "f1_micro": float(f1_micro),
    "f1_macro": float(f1_macro),
    "f1_weighted": float(f1_weighted),
    "per_feature_f1_micro": {k: float(v) for k, v in zip(target_cols, f1_per_feature_micro)},
    "per_feature_f1_macro": {k: float(v) for k, v in zip(target_cols, f1_per_feature_macro)},
    "per_feature_f1_weighted": {k: float(v) for k, v in zip(target_cols, f1_per_feature_weighted)},
}
with (OUTPUT_DIR / "test_f1_metrics.json").open("w", encoding="utf-8") as f:
    json.dump(f1_json, f, ensure_ascii=False, indent=2)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

from IPython.display import display

pd.set_option("display.colheader_justify", "left")

def _left(df):
    return df.style.set_properties(**{"text-align": "left"}).set_table_styles([
        {"selector": "th", "props": [("text-align", "left")]},
    ])

display(_left(summary_df))
display(_left(per_feature_df))
# Out:
# <style type="text/css">
# #T_4c5d3 th {
#   text-align: left;
# }
# #T_4c5d3_row0_col0, #T_4c5d3_row0_col1, #T_4c5d3_row1_col0, #T_4c5d3_row1_col1, #T_4c5d3_row2_col0, #T_4c5d3_row2_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_4c5d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c5d3_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_4c5d3_level0_col1" class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c5d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c5d3_row0_col0" class="data row0 col0" >f1_micro</td>
#       <td id="T_4c5d3_row0_col1" class="data row0 col1" >0.862597</td>
#     </tr>
#     <tr>
#       <th id="T_4c5d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c5d3_row1_col0" class="data row1 col0" >f1_macro</td>
#       <td id="T_4c5d3_row1_col1" class="data row1 col1" >0.767394</td>
#     </tr>
#     <tr>
#       <th id="T_4c5d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c5d3_row2_col0" class="data row2 col0" >f1_weighted</td>
#       <td id="T_4c5d3_row2_col1" class="data row2 col1" >0.859911</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2d652 th {
#   text-align: left;
# }
# #T_2d652_row0_col0, #T_2d652_row0_col1, #T_2d652_row0_col2, #T_2d652_row0_col3, #T_2d652_row0_col4, #T_2d652_row1_col0, #T_2d652_row1_col1, #T_2d652_row1_col2, #T_2d652_row1_col3, #T_2d652_row1_col4, #T_2d652_row2_col0, #T_2d652_row2_col1, #T_2d652_row2_col2, #T_2d652_row2_col3, #T_2d652_row2_col4, #T_2d652_row3_col0, #T_2d652_row3_col1, #T_2d652_row3_col2, #T_2d652_row3_col3, #T_2d652_row3_col4, #T_2d652_row4_col0, #T_2d652_row4_col1, #T_2d652_row4_col2, #T_2d652_row4_col3, #T_2d652_row4_col4, #T_2d652_row5_col0, #T_2d652_row5_col1, #T_2d652_row5_col2, #T_2d652_row5_col3, #T_2d652_row5_col4, #T_2d652_row6_col0, #T_2d652_row6_col1, #T_2d652_row6_col2, #T_2d652_row6_col3, #T_2d652_row6_col4, #T_2d652_row7_col0, #T_2d652_row7_col1, #T_2d652_row7_col2, #T_2d652_row7_col3, #T_2d652_row7_col4, #T_2d652_row8_col0, #T_2d652_row8_col1, #T_2d652_row8_col2, #T_2d652_row8_col3, #T_2d652_row8_col4, #T_2d652_row9_col0, #T_2d652_row9_col1, #T_2d652_row9_col2, #T_2d652_row9_col3, #T_2d652_row9_col4, #T_2d652_row10_col0, #T_2d652_row10_col1, #T_2d652_row10_col2, #T_2d652_row10_col3, #T_2d652_row10_col4, #T_2d652_row11_col0, #T_2d652_row11_col1, #T_2d652_row11_col2, #T_2d652_row11_col3, #T_2d652_row11_col4, #T_2d652_row12_col0, #T_2d652_row12_col1, #T_2d652_row12_col2, #T_2d652_row12_col3, #T_2d652_row12_col4, #T_2d652_row13_col0, #T_2d652_row13_col1, #T_2d652_row13_col2, #T_2d652_row13_col3, #T_2d652_row13_col4, #T_2d652_row14_col0, #T_2d652_row14_col1, #T_2d652_row14_col2, #T_2d652_row14_col3, #T_2d652_row14_col4, #T_2d652_row15_col0, #T_2d652_row15_col1, #T_2d652_row15_col2, #T_2d652_row15_col3, #T_2d652_row15_col4, #T_2d652_row16_col0, #T_2d652_row16_col1, #T_2d652_row16_col2, #T_2d652_row16_col3, #T_2d652_row16_col4, #T_2d652_row17_col0, #T_2d652_row17_col1, #T_2d652_row17_col2, #T_2d652_row17_col3, #T_2d652_row17_col4, #T_2d652_row18_col0, #T_2d652_row18_col1, #T_2d652_row18_col2, #T_2d652_row18_col3, #T_2d652_row18_col4, #T_2d652_row19_col0, #T_2d652_row19_col1, #T_2d652_row19_col2, #T_2d652_row19_col3, #T_2d652_row19_col4, #T_2d652_row20_col0, #T_2d652_row20_col1, #T_2d652_row20_col2, #T_2d652_row20_col3, #T_2d652_row20_col4, #T_2d652_row21_col0, #T_2d652_row21_col1, #T_2d652_row21_col2, #T_2d652_row21_col3, #T_2d652_row21_col4, #T_2d652_row22_col0, #T_2d652_row22_col1, #T_2d652_row22_col2, #T_2d652_row22_col3, #T_2d652_row22_col4, #T_2d652_row23_col0, #T_2d652_row23_col1, #T_2d652_row23_col2, #T_2d652_row23_col3, #T_2d652_row23_col4, #T_2d652_row24_col0, #T_2d652_row24_col1, #T_2d652_row24_col2, #T_2d652_row24_col3, #T_2d652_row24_col4, #T_2d652_row25_col0, #T_2d652_row25_col1, #T_2d652_row25_col2, #T_2d652_row25_col3, #T_2d652_row25_col4, #T_2d652_row26_col0, #T_2d652_row26_col1, #T_2d652_row26_col2, #T_2d652_row26_col3, #T_2d652_row26_col4, #T_2d652_row27_col0, #T_2d652_row27_col1, #T_2d652_row27_col2, #T_2d652_row27_col3, #T_2d652_row27_col4, #T_2d652_row28_col0, #T_2d652_row28_col1, #T_2d652_row28_col2, #T_2d652_row28_col3, #T_2d652_row28_col4, #T_2d652_row29_col0, #T_2d652_row29_col1, #T_2d652_row29_col2, #T_2d652_row29_col3, #T_2d652_row29_col4, #T_2d652_row30_col0, #T_2d652_row30_col1, #T_2d652_row30_col2, #T_2d652_row30_col3, #T_2d652_row30_col4, #T_2d652_row31_col0, #T_2d652_row31_col1, #T_2d652_row31_col2, #T_2d652_row31_col3, #T_2d652_row31_col4, #T_2d652_row32_col0, #T_2d652_row32_col1, #T_2d652_row32_col2, #T_2d652_row32_col3, #T_2d652_row32_col4, #T_2d652_row33_col0, #T_2d652_row33_col1, #T_2d652_row33_col2, #T_2d652_row33_col3, #T_2d652_row33_col4, #T_2d652_row34_col0, #T_2d652_row34_col1, #T_2d652_row34_col2, #T_2d652_row34_col3, #T_2d652_row34_col4, #T_2d652_row35_col0, #T_2d652_row35_col1, #T_2d652_row35_col2, #T_2d652_row35_col3, #T_2d652_row35_col4, #T_2d652_row36_col0, #T_2d652_row36_col1, #T_2d652_row36_col2, #T_2d652_row36_col3, #T_2d652_row36_col4, #T_2d652_row37_col0, #T_2d652_row37_col1, #T_2d652_row37_col2, #T_2d652_row37_col3, #T_2d652_row37_col4, #T_2d652_row38_col0, #T_2d652_row38_col1, #T_2d652_row38_col ...

# %% [markdown]
# ## H. Stable features export

# %%
def export_stable_features(per_feature_df: pd.DataFrame, thresholds=(0.7, 0.8, 0.9)):
    per_feature_xlsx_path = OUTPUT_DIR / "per_feature_f1_table.xlsx"

    for threshold in thresholds:
        stable_df = per_feature_df.loc[
            per_feature_df["f1_macro"].astype(float) >= float(threshold)
        ].reset_index(drop=True)

        display(_left(stable_df))

        with pd.ExcelWriter(per_feature_xlsx_path) as writer:
            per_feature_df.to_excel(writer, index=False, sheet_name="per_feature")
            stable_df.to_excel(writer, index=False, sheet_name="macro_ge_threshold")

        stable_export_path = OUTPUT_DIR / f"per_feature_macro_ge_{threshold:.2f}.xlsx"
        stable_df.to_excel(stable_export_path, index=False, sheet_name="macro_ge_threshold")


export_stable_features(per_feature_df)
# Out:
# <style type="text/css">
# #T_b9eec th {
#   text-align: left;
# }
# #T_b9eec_row0_col0, #T_b9eec_row0_col1, #T_b9eec_row0_col2, #T_b9eec_row0_col3, #T_b9eec_row0_col4, #T_b9eec_row1_col0, #T_b9eec_row1_col1, #T_b9eec_row1_col2, #T_b9eec_row1_col3, #T_b9eec_row1_col4, #T_b9eec_row2_col0, #T_b9eec_row2_col1, #T_b9eec_row2_col2, #T_b9eec_row2_col3, #T_b9eec_row2_col4, #T_b9eec_row3_col0, #T_b9eec_row3_col1, #T_b9eec_row3_col2, #T_b9eec_row3_col3, #T_b9eec_row3_col4, #T_b9eec_row4_col0, #T_b9eec_row4_col1, #T_b9eec_row4_col2, #T_b9eec_row4_col3, #T_b9eec_row4_col4, #T_b9eec_row5_col0, #T_b9eec_row5_col1, #T_b9eec_row5_col2, #T_b9eec_row5_col3, #T_b9eec_row5_col4, #T_b9eec_row6_col0, #T_b9eec_row6_col1, #T_b9eec_row6_col2, #T_b9eec_row6_col3, #T_b9eec_row6_col4, #T_b9eec_row7_col0, #T_b9eec_row7_col1, #T_b9eec_row7_col2, #T_b9eec_row7_col3, #T_b9eec_row7_col4, #T_b9eec_row8_col0, #T_b9eec_row8_col1, #T_b9eec_row8_col2, #T_b9eec_row8_col3, #T_b9eec_row8_col4, #T_b9eec_row9_col0, #T_b9eec_row9_col1, #T_b9eec_row9_col2, #T_b9eec_row9_col3, #T_b9eec_row9_col4, #T_b9eec_row10_col0, #T_b9eec_row10_col1, #T_b9eec_row10_col2, #T_b9eec_row10_col3, #T_b9eec_row10_col4, #T_b9eec_row11_col0, #T_b9eec_row11_col1, #T_b9eec_row11_col2, #T_b9eec_row11_col3, #T_b9eec_row11_col4, #T_b9eec_row12_col0, #T_b9eec_row12_col1, #T_b9eec_row12_col2, #T_b9eec_row12_col3, #T_b9eec_row12_col4, #T_b9eec_row13_col0, #T_b9eec_row13_col1, #T_b9eec_row13_col2, #T_b9eec_row13_col3, #T_b9eec_row13_col4, #T_b9eec_row14_col0, #T_b9eec_row14_col1, #T_b9eec_row14_col2, #T_b9eec_row14_col3, #T_b9eec_row14_col4, #T_b9eec_row15_col0, #T_b9eec_row15_col1, #T_b9eec_row15_col2, #T_b9eec_row15_col3, #T_b9eec_row15_col4, #T_b9eec_row16_col0, #T_b9eec_row16_col1, #T_b9eec_row16_col2, #T_b9eec_row16_col3, #T_b9eec_row16_col4, #T_b9eec_row17_col0, #T_b9eec_row17_col1, #T_b9eec_row17_col2, #T_b9eec_row17_col3, #T_b9eec_row17_col4, #T_b9eec_row18_col0, #T_b9eec_row18_col1, #T_b9eec_row18_col2, #T_b9eec_row18_col3, #T_b9eec_row18_col4, #T_b9eec_row19_col0, #T_b9eec_row19_col1, #T_b9eec_row19_col2, #T_b9eec_row19_col3, #T_b9eec_row19_col4, #T_b9eec_row20_col0, #T_b9eec_row20_col1, #T_b9eec_row20_col2, #T_b9eec_row20_col3, #T_b9eec_row20_col4, #T_b9eec_row21_col0, #T_b9eec_row21_col1, #T_b9eec_row21_col2, #T_b9eec_row21_col3, #T_b9eec_row21_col4, #T_b9eec_row22_col0, #T_b9eec_row22_col1, #T_b9eec_row22_col2, #T_b9eec_row22_col3, #T_b9eec_row22_col4, #T_b9eec_row23_col0, #T_b9eec_row23_col1, #T_b9eec_row23_col2, #T_b9eec_row23_col3, #T_b9eec_row23_col4, #T_b9eec_row24_col0, #T_b9eec_row24_col1, #T_b9eec_row24_col2, #T_b9eec_row24_col3, #T_b9eec_row24_col4, #T_b9eec_row25_col0, #T_b9eec_row25_col1, #T_b9eec_row25_col2, #T_b9eec_row25_col3, #T_b9eec_row25_col4, #T_b9eec_row26_col0, #T_b9eec_row26_col1, #T_b9eec_row26_col2, #T_b9eec_row26_col3, #T_b9eec_row26_col4, #T_b9eec_row27_col0, #T_b9eec_row27_col1, #T_b9eec_row27_col2, #T_b9eec_row27_col3, #T_b9eec_row27_col4, #T_b9eec_row28_col0, #T_b9eec_row28_col1, #T_b9eec_row28_col2, #T_b9eec_row28_col3, #T_b9eec_row28_col4, #T_b9eec_row29_col0, #T_b9eec_row29_col1, #T_b9eec_row29_col2, #T_b9eec_row29_col3, #T_b9eec_row29_col4, #T_b9eec_row30_col0, #T_b9eec_row30_col1, #T_b9eec_row30_col2, #T_b9eec_row30_col3, #T_b9eec_row30_col4, #T_b9eec_row31_col0, #T_b9eec_row31_col1, #T_b9eec_row31_col2, #T_b9eec_row31_col3, #T_b9eec_row31_col4, #T_b9eec_row32_col0, #T_b9eec_row32_col1, #T_b9eec_row32_col2, #T_b9eec_row32_col3, #T_b9eec_row32_col4, #T_b9eec_row33_col0, #T_b9eec_row33_col1, #T_b9eec_row33_col2, #T_b9eec_row33_col3, #T_b9eec_row33_col4, #T_b9eec_row34_col0, #T_b9eec_row34_col1, #T_b9eec_row34_col2, #T_b9eec_row34_col3, #T_b9eec_row34_col4, #T_b9eec_row35_col0, #T_b9eec_row35_col1, #T_b9eec_row35_col2, #T_b9eec_row35_col3, #T_b9eec_row35_col4, #T_b9eec_row36_col0, #T_b9eec_row36_col1, #T_b9eec_row36_col2, #T_b9eec_row36_col3, #T_b9eec_row36_col4, #T_b9eec_row37_col0, #T_b9eec_row37_col1, #T_b9eec_row37_col2, #T_b9eec_row37_col3, #T_b9eec_row37_col4, #T_b9eec_row38_col0, #T_b9eec_row38_col1, #T_b9eec_row38_col ...
#   text-align: left;
# }
# </style>
# <table id="T_b9eec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9eec_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_b9eec_level0_col1" class="col_heading level0 col1" >num_labels</th>
#       <th id="T_b9eec_level0_col2" class="col_heading level0 col2" >f1_micro</th>
#       <th id="T_b9eec_level0_col3" class="col_heading level0 col3" >f1_macro</th>
#       <th id="T_b9eec_level0_col4" class="col_heading level0 col4" >f1_weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9eec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9eec_row0_col0" class="data row0 col0" >Голова (без особенностей)</td>
#       <td id="T_b9eec_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_b9eec_row0_col2" class="data row0 col2" >0.805405</td>
#       <td id="T_b9eec_row0_col3" class="data row0 col3" >0.732667</td>
#       <td id="T_b9eec_row0_col4" class="data row0 col4" >0.785054</td>
#     </tr>
#     <tr>
#       <th id="T_b9eec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9eec_row1_col0" class="data row1 col0" >Детали (лицо) (волосы (шапка))</td>
#       <td id="T_b9eec_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_b9eec_row1_col2" class="data row1 col2" >0.939189</td>
#       <td id="T_b9eec_row1_col3" class="data row1 col3" >0.879417</td>
#       <td id="T_b9eec_row1_col4" class="data row1 col4" >0.941598</td>
#     </tr>
#     <tr>
#       <th id="T_b9eec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9eec_row2_col0" class="data row2 col0" >Детали (лицо) (глаза (один или оба))</td>
#       <td id="T_b9eec_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_b9eec_row2_col2" class="data row2 col2" >0.982432</td>
#       <td id="T_b9eec_row2_col3" class="data row2 col3" >0.898385</td>
#       <td id="T_b9eec_row2_col4" class="data row2 col4" >0.982058</td>
#     </tr>
#     <tr>
#       <th id="T_b9eec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9eec_row3_col0" class="data row3 col0" >Детали (лицо) (нос)</td>
#       <td id="T_b9eec_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_b9eec_row3_col2" class="data row3 col2" >0.821622</td>
#       <td id="T_b9eec_row3_col3" class="data row3 col3" >0.804670</td>
#       <td id="T_b9eec_row3_col4" class="data row3 col4" >0.825043</td>
#     </tr>
#     <tr>
#       <th id="T_b9eec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9eec_row4_col0" class="data row4 col0" >Детали (лицо) (рот)</td>
#       <td id="T_b9eec_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_b9eec_row4_col2" class="data row4 col2" >0.967568</td>
#       <td id="T_b9eec_row4_col3" class="data row4 col3" >0.848547</td>
#       <td id="T_b9eec_row4_col4" class="data row4 col4" >0.965753</td>
#     </tr>
#     <tr>
#       <th id="T_b9eec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9eec_row5_col0" class="data row5 col0" >Детали (лицо) (уши)</td>
#       <td id="T_b9eec_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_b9eec_row5_col2" class="data row5 col2" >0.877027</td>
#       <td id="T_b9eec_row5_col3" class="data row5 col3" >0.840266</td>
#       <td id="T_b9eec_row5_col4" class="data row5 col4" >0.872781</td>
#     </tr>
#     <tr>
#       <th id="T_b9eec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b9eec_row6_col0" class="data row6 col0" >Дополнительные детали изображения фигуры (отсутствуют)</td>
#       <td id="T_b9eec_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_b9eec_row6_col2" class="data row6 col2" >0.863514</td>
#       <td id="T_b9eec_row6_col3" cla
# <style type="text/css">
# #T_2bc95 th {
#   text-align: left;
# }
# #T_2bc95_row0_col0, #T_2bc95_row0_col1, #T_2bc95_row0_col2, #T_2bc95_row0_col3, #T_2bc95_row0_col4, #T_2bc95_row1_col0, #T_2bc95_row1_col1, #T_2bc95_row1_col2, #T_2bc95_row1_col3, #T_2bc95_row1_col4, #T_2bc95_row2_col0, #T_2bc95_row2_col1, #T_2bc95_row2_col2, #T_2bc95_row2_col3, #T_2bc95_row2_col4, #T_2bc95_row3_col0, #T_2bc95_row3_col1, #T_2bc95_row3_col2, #T_2bc95_row3_col3, #T_2bc95_row3_col4, #T_2bc95_row4_col0, #T_2bc95_row4_col1, #T_2bc95_row4_col2, #T_2bc95_row4_col3, #T_2bc95_row4_col4, #T_2bc95_row5_col0, #T_2bc95_row5_col1, #T_2bc95_row5_col2, #T_2bc95_row5_col3, #T_2bc95_row5_col4, #T_2bc95_row6_col0, #T_2bc95_row6_col1, #T_2bc95_row6_col2, #T_2bc95_row6_col3, #T_2bc95_row6_col4, #T_2bc95_row7_col0, #T_2bc95_row7_col1, #T_2bc95_row7_col2, #T_2bc95_row7_col3, #T_2bc95_row7_col4, #T_2bc95_row8_col0, #T_2bc95_row8_col1, #T_2bc95_row8_col2, #T_2bc95_row8_col3, #T_2bc95_row8_col4, #T_2bc95_row9_col0, #T_2bc95_row9_col1, #T_2bc95_row9_col2, #T_2bc95_row9_col3, #T_2bc95_row9_col4, #T_2bc95_row10_col0, #T_2bc95_row10_col1, #T_2bc95_row10_col2, #T_2bc95_row10_col3, #T_2bc95_row10_col4, #T_2bc95_row11_col0, #T_2bc95_row11_col1, #T_2bc95_row11_col2, #T_2bc95_row11_col3, #T_2bc95_row11_col4, #T_2bc95_row12_col0, #T_2bc95_row12_col1, #T_2bc95_row12_col2, #T_2bc95_row12_col3, #T_2bc95_row12_col4, #T_2bc95_row13_col0, #T_2bc95_row13_col1, #T_2bc95_row13_col2, #T_2bc95_row13_col3, #T_2bc95_row13_col4, #T_2bc95_row14_col0, #T_2bc95_row14_col1, #T_2bc95_row14_col2, #T_2bc95_row14_col3, #T_2bc95_row14_col4, #T_2bc95_row15_col0, #T_2bc95_row15_col1, #T_2bc95_row15_col2, #T_2bc95_row15_col3, #T_2bc95_row15_col4, #T_2bc95_row16_col0, #T_2bc95_row16_col1, #T_2bc95_row16_col2, #T_2bc95_row16_col3, #T_2bc95_row16_col4, #T_2bc95_row17_col0, #T_2bc95_row17_col1, #T_2bc95_row17_col2, #T_2bc95_row17_col3, #T_2bc95_row17_col4, #T_2bc95_row18_col0, #T_2bc95_row18_col1, #T_2bc95_row18_col2, #T_2bc95_row18_col3, #T_2bc95_row18_col4, #T_2bc95_row19_col0, #T_2bc95_row19_col1, #T_2bc95_row19_col2, #T_2bc95_row19_col3, #T_2bc95_row19_col4, #T_2bc95_row20_col0, #T_2bc95_row20_col1, #T_2bc95_row20_col2, #T_2bc95_row20_col3, #T_2bc95_row20_col4, #T_2bc95_row21_col0, #T_2bc95_row21_col1, #T_2bc95_row21_col2, #T_2bc95_row21_col3, #T_2bc95_row21_col4, #T_2bc95_row22_col0, #T_2bc95_row22_col1, #T_2bc95_row22_col2, #T_2bc95_row22_col3, #T_2bc95_row22_col4, #T_2bc95_row23_col0, #T_2bc95_row23_col1, #T_2bc95_row23_col2, #T_2bc95_row23_col3, #T_2bc95_row23_col4, #T_2bc95_row24_col0, #T_2bc95_row24_col1, #T_2bc95_row24_col2, #T_2bc95_row24_col3, #T_2bc95_row24_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_2bc95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bc95_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_2bc95_level0_col1" class="col_heading level0 col1" >num_labels</th>
#       <th id="T_2bc95_level0_col2" class="col_heading level0 col2" >f1_micro</th>
#       <th id="T_2bc95_level0_col3" class="col_heading level0 col3" >f1_macro</th>
#       <th id="T_2bc95_level0_col4" class="col_heading level0 col4" >f1_weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bc95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bc95_row0_col0" class="data row0 col0" >Детали (лицо) (волосы (шапка))</td>
#       <td id="T_2bc95_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_2bc95_row0_col2" class="data row0 col2" >0.939189</td>
#       <td id="T_2bc95_row0_col3" class="data row0 col3" >0.879417</td>
#       <td id="T_2bc95_row0_col4" class="data row0 col4" >0.941598</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2bc95_row1_col0" class="data row1 col0" >Детали (лицо) (глаза (один или оба))</td>
#       <td id="T_2bc95_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_2bc95_row1_col2" class="data row1 col2" >0.982432</td>
#       <td id="T_2bc95_row1_col3" class="data row1 col3" >0.898385</td>
#       <td id="T_2bc95_row1_col4" class="data row1 col4" >0.982058</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2bc95_row2_col0" class="data row2 col0" >Детали (лицо) (нос)</td>
#       <td id="T_2bc95_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_2bc95_row2_col2" class="data row2 col2" >0.821622</td>
#       <td id="T_2bc95_row2_col3" class="data row2 col3" >0.804670</td>
#       <td id="T_2bc95_row2_col4" class="data row2 col4" >0.825043</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2bc95_row3_col0" class="data row3 col0" >Детали (лицо) (рот)</td>
#       <td id="T_2bc95_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_2bc95_row3_col2" class="data row3 col2" >0.967568</td>
#       <td id="T_2bc95_row3_col3" class="data row3 col3" >0.848547</td>
#       <td id="T_2bc95_row3_col4" class="data row3 col4" >0.965753</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2bc95_row4_col0" class="data row4 col0" >Детали (лицо) (уши)</td>
#       <td id="T_2bc95_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_2bc95_row4_col2" class="data row4 col2" >0.877027</td>
#       <td id="T_2bc95_row4_col3" class="data row4 col3" >0.840266</td>
#       <td id="T_2bc95_row4_col4" class="data row4 col4" >0.872781</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2bc95_row5_col0" class="data row5 col0" >Дополнительные детали изображения фигуры (отсутствуют)</td>
#       <td id="T_2bc95_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_2bc95_row5_col2" class="data row5 col2" >0.863514</td>
#       <td id="T_2bc95_row5_col3" class="data row5 col3" >0.859636</td>
#       <td id="T_2bc95_row5_col4" class="data row5 col4" >0.863860</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2bc95_row6_col0" class="data row6 col0" >Дополнительные детали изображения фигуры (пуговицы)</td>
#       <td id="T_2bc95_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_2bc95_row6_col2" class="data row6 col2" >0.966216</td>
#       <td id="T_2bc95_row6_col3" class="data row6 col3" >0.804586</td>
#       <td id="T_2bc95_row6_col4" class="data row6 col4" >0.966937</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2bc95_row7_col0" class="data row7 col0" >Дополнительные детали изображения фигуры (украшения)</td>
#       <td id="T_2bc95_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_2bc95_row7_col2" class="data row7 col2" >0.882432</td>
#       <td id="T_2bc95_row7_col3" class="data row7 col3" >0.824566</td>
#       <td id="T_2bc95_row7_col4" class="data row7 col4" >0.880662</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2bc95_row8_col0" class="data row8 col0" >Кисть (отсутствует)</td>
#       <td id="T_2bc95_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_2bc95_row8_col2" class="data row8 col2" >0.822973</td>
#       <td id="T_2bc95_row8_col3" class="data row8 col3" >0.821916</td>
#       <td id="T_2bc95_row8_col4" class="data row8 col4" >0.823548</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2bc95_row9_col0" class="data row9 col0" >Ладонь, пальцы (изображены пальцы)</td>
#       <td id="T_2bc95_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_2bc95_row9_col2" class="data row9 col2" >0.882432</td>
#       <td id="T_2bc95_row9_col3" class="data row9 col3" >0.882415</td>
#       <td id="T_2bc95_row9_col4" class="data row9 col4" >0.882504</td>
#     </tr>
#     <tr>
#       <th id="T_2bc95_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2bc95_row10_col0" class="dat
# <style type="text/css">
# #T_e6387 th {
#   text-align: left;
# }
# #T_e6387_row0_col0, #T_e6387_row0_col1, #T_e6387_row0_col2, #T_e6387_row0_col3, #T_e6387_row0_col4, #T_e6387_row1_col0, #T_e6387_row1_col1, #T_e6387_row1_col2, #T_e6387_row1_col3, #T_e6387_row1_col4, #T_e6387_row2_col0, #T_e6387_row2_col1, #T_e6387_row2_col2, #T_e6387_row2_col3, #T_e6387_row2_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_e6387">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6387_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_e6387_level0_col1" class="col_heading level0 col1" >num_labels</th>
#       <th id="T_e6387_level0_col2" class="col_heading level0 col2" >f1_micro</th>
#       <th id="T_e6387_level0_col3" class="col_heading level0 col3" >f1_macro</th>
#       <th id="T_e6387_level0_col4" class="col_heading level0 col4" >f1_weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6387_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6387_row0_col0" class="data row0 col0" >Положение рук (за спиной или в карманах)</td>
#       <td id="T_e6387_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_e6387_row0_col2" class="data row0 col2" >0.974324</td>
#       <td id="T_e6387_row0_col3" class="data row0 col3" >0.918175</td>
#       <td id="T_e6387_row0_col4" class="data row0 col4" >0.974599</td>
#     </tr>
#     <tr>
#       <th id="T_e6387_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6387_row1_col0" class="data row1 col0" >Ступни (отсутствуют)</td>
#       <td id="T_e6387_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_e6387_row1_col2" class="data row1 col2" >0.948649</td>
#       <td id="T_e6387_row1_col3" class="data row1 col3" >0.930777</td>
#       <td id="T_e6387_row1_col4" class="data row1 col4" >0.949124</td>
#     </tr>
#     <tr>
#       <th id="T_e6387_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6387_row2_col0" class="data row2 col0" >Шея (отсутствует)</td>
#       <td id="T_e6387_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_e6387_row2_col2" class="data row2 col2" >0.932432</td>
#       <td id="T_e6387_row2_col3" class="data row2 col3" >0.911483</td>
#       <td id="T_e6387_row2_col4" class="data row2 col4" >0.931036</td>
#     </tr>
#   </tbody>
# </table>
